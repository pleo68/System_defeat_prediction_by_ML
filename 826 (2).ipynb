# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import random
import lightgbm as lgb
import re
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings(action='ignore')

# 필요한 함수 정의
def make_datetime(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    year  = int(x[:4])
    month = int(x[4:6])
    day   = int(x[6:8])
    hour  = int(x[8:10])
    #mim  = int(x[10:12])
    #sec  = int(x[12:])
    return dt.datetime(year, month, day, hour)

def string2num(x):
    # (,)( )과 같은 불필요한 데이터 정제
    x = re.sub(r"[^0-9]+", '', str(x))
    if x =='':
        return 0
    else:
        return int(x)


PATH = './data/'

# %%
train_err  = pd.read_csv(PATH+'train_err_data.csv')
display(train_err.head())
# Out:
#    user_id            time model_nm       fwver  errtype errcode
# 0    10000  20201101025616  model_3  05.15.2138       15       1
# 1    10000  20201101030309  model_3  05.15.2138       12       1
# 2    10000  20201101030309  model_3  05.15.2138       11       1
# 3    10000  20201101050514  model_3  05.15.2138       16       1
# 4    10000  20201101050515  model_3  05.15.2138        4       0

# %%
train_user_id_max = 24999
train_user_id_min = 10000
train_user_number = 15000

# %%
## days의 변수로 만들기
train_err['datetime'] = train_err['time'].apply(make_datetime)
min_day = train_err.datetime.min().date()

train_err['days'] = train_err.loc[:,'datetime'].dt.date - min_day
train_err['days'] = train_err['days'].dt.days
display(train_err)
# Out:
#           user_id            time model_nm       fwver  errtype errcode  \
# 0           10000  20201101025616  model_3  05.15.2138       15       1
# 1           10000  20201101030309  model_3  05.15.2138       12       1
# 2           10000  20201101030309  model_3  05.15.2138       11       1
# 3           10000  20201101050514  model_3  05.15.2138       16       1
# 4           10000  20201101050515  model_3  05.15.2138        4       0
# ...           ...             ...      ...         ...      ...     ...
# 16554658    24999  20201130163051  model_3  05.15.2138       15       1
# 16554659    24999  20201130172625  model_3  05.15.2138       16       1
# 16554660    24999  20201130172625  model_3  05.15.2138        4       0
# 16554661    24999  20201130172631  model_3  05.15.2138        4       0
# 16554662    24999  20201130210625  model_3  05.15.2138       15       1
#
#                     datetime  days
# 0        2020-11-01 02:00:00     1
# 1        2020-11-01 03:00:00     1
# 2        2020-11-01 03:00:00     1
# 3        2020-11-01 05:00:00     1
# 4        2020-11-01 05:00:00     1
# ...                      ...   ...
# 16554658 2020-11-30 16:00:00    30
# 16554659 2020-11-30 17:00:00    30
# 16554660 2020-11-30 17:00:00    30
# 16554661 2020-11-30 17:00:00    30
# 16554662 2020-11-30 21:00:00    30
#
# [16554663 rows x 8 columns]

# %%
##시간별 데이터 만드는 코딩
def time_encoding(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    day   = int(x[6:8])
    hour  = int(x[8:10])
    y = day*100 + hour
    for i in range(30):
        if y == (i+1)*100:
            return 0
        if y == (i+1)*100 + 1:
            return 1
        if y == (i+1)*100 + 2:
            return 2
        if y == (i+1)*100 + 3:
            return 3
        if y == (i+1)*100 + 4:
            return 4
        if y == (i+1)*100 + 5:
            return 5
        if y == (i+1)*100 + 6:
            return 6
        if y == (i+1)*100 + 7:
            return 7
        if y == (i+1)*100 + 8:
            return 8
        if y == (i+1)*100 + 9:
            return 9
        if y == (i+1)*100 + 10:
            return 10
        if y == (i+1)*100 + 11:
            return 11
        if y == (i+1)*100 + 12:
            return 12
        if y == (i+1)*100 + 13:
            return 13
        if y == (i+1)*100 + 14:
            return 14
        if y == (i+1)*100 + 15:
            return 15
        if y == (i+1)*100 + 16:
            return 16
        if y == (i+1)*100 + 17:
            return 17
        if y == (i+1)*100 + 18:
            return 18
        if y == (i+1)*100 + 19:
            return 19
        if y == (i+1)*100 + 20:
            return 20
        if y == (i+1)*100 + 21:
            return 21
        if y == (i+1)*100 + 22:
            return 22
        if y == (i+1)*100 + 23:
            return 23
        if day == 31: # 10월 31일 23:59의 경우
            return 0

# %%
#적용하기
train_err['timeslot'] = train_err['time'].apply(time_encoding)

# %%
train_err[train_err['time']==20201031235959] ## 1031일 확인하기
#timeslot 추가분 /// 31변수가 NAN으로 입력됨
#train_err[train_err['timeslot'].isnull()==True]

## 날짜 데이터는 1031 ~ 1202 까지 존재
# Out:
#           user_id            time model_nm       fwver  errtype errcode  \
# 6409135     15801  20201031235959  model_0  04.22.1750       16       1
# 9204586     18418  20201031235959  model_0  04.22.1750       26       1
# 12134438    20974  20201031235959  model_0  04.22.1750       26       1
# 13424899    22249  20201031235959  model_0  04.22.1750       26       1
# 13585684    22385  20201031235959  model_2  04.33.1185       26       1
#
#                     datetime  days  timeslot
# 6409135  2020-10-31 23:00:00     0         0
# 9204586  2020-10-31 23:00:00     0         0
# 12134438 2020-10-31 23:00:00     0         0
# 13424899 2020-10-31 23:00:00     0         0
# 13585684 2020-10-31 23:00:00     0         0

# %%
train_err
# Out:
#           user_id            time model_nm       fwver  errtype errcode  \
# 0           10000  20201101025616  model_3  05.15.2138       15       1
# 1           10000  20201101030309  model_3  05.15.2138       12       1
# 2           10000  20201101030309  model_3  05.15.2138       11       1
# 3           10000  20201101050514  model_3  05.15.2138       16       1
# 4           10000  20201101050515  model_3  05.15.2138        4       0
# ...           ...             ...      ...         ...      ...     ...
# 16554658    24999  20201130163051  model_3  05.15.2138       15       1
# 16554659    24999  20201130172625  model_3  05.15.2138       16       1
# 16554660    24999  20201130172625  model_3  05.15.2138        4       0
# 16554661    24999  20201130172631  model_3  05.15.2138        4       0
# 16554662    24999  20201130210625  model_3  05.15.2138       15       1
#
#                     datetime  days  timeslot
# 0        2020-11-01 02:00:00     1         2
# 1        2020-11-01 03:00:00     1         3
# 2        2020-11-01 03:00:00     1         3
# 3        2020-11-01 05:00:00     1         5
# 4        2020-11-01 05:00:00     1         5
# ...                      ...   ...       ...
# 16554658 2020-11-30 16:00:00    30        16
# 16554659 2020-11-30 17:00:00    30        17
# 16554660 2020-11-30 17:00:00    30        17
# 16554661 2020-11-30 17:00:00    30        17
# 16554662 2020-11-30 21:00:00    30        21
#
# [16554663 rows x 9 columns]

# %%
train_err=train_err.drop(columns=['datetime','time']) ## 시간처리 완료로 시간 데이터 드랍
#train_err = train_errf.drop(columns=['user_id','model_nm']) #ID 드랍하고 모델넘버는 펌웨어 버전과 연관이 있기에 드랍

# %%
len(test_err['errtype'].unique())
# Out:
# 41

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
encoder = LabelEncoder()
encoder.fit(train_err['fwver'].astype('|S80'))
labels_fwver = encoder.transform(train_err['fwver'].astype('|S80'))
train_err = pd.concat([train_err,pd.Series(labels_fwver)],axis=1)
train_err.rename(columns = {0 : 'labels_fwver'}, inplace = True)

# %%
fwver_label = train_err[['user_id','labels_fwver']].values
fwver_check = np.zeros((train_user_number,len(train_err['labels_fwver'].unique())))

for person_idx, ch in tqdm(fwver_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    fwver_check[person_idx - train_user_id_min,ch - 1] += 1
fwver_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:45<00:00, 362509.09it/s]
# (15000, 37)

# %%
days_label = train_err[['user_id','days']].values
days_check = np.zeros((train_user_number,len(train_err['days'].unique())))

for person_idx, ch in tqdm(days_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    days_check[person_idx - train_user_id_min,ch - 1] += 1
days_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:45<00:00, 365037.50it/s]
# (15000, 33)

# %%
timeslot_label = train_err[['user_id','timeslot']].values
timeslot_check = np.zeros((train_user_number,len(train_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check[person_idx - train_user_id_min,ch - 1] += 1
timeslot_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:47<00:00, 349340.50it/s]
# (15000, 24)

# %%
id_error = train_err[['user_id','errtype']].values
error = np.zeros((train_user_number,42))

for person_idx, err in tqdm(id_error):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error[person_idx - train_user_id_min,err - 1] += 1
error.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:46<00:00, 356025.44it/s]
# (15000, 42)

# %%
x_concat1 = np.concatenate((fwver_check, days_check), axis=1) ## 펌웨어 버전 + 날짜 
x_concat2 = np.concatenate((x_concat1, timeslot_check), axis=1) ## 펌웨어 버전 + 날짜 +시간 
x_concat3 = np.concatenate((x_concat2, error), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러

# %%
train_prob = pd.read_csv(PATH+'train_problem_data.csv')
problem = np.zeros(15000)
# error와 동일한 방법으로 person_idx - 10000 위치에 
# person_idx의 problem이 한 번이라도 발생했다면 1
# 없다면 0
problem[train_prob.user_id.unique()-10000] = 1 
problem.shape
# Out:
# (15000,)

# %%
# 변수 이름 변경
# error  -> train_x
# problem-> train_y

train_x = x_concat3
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 136)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=10, shuffle=True, random_state=150)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 100
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4543, number of negative: 8957
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20429
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 114
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.336519 -> initscore=-0.678848
# [LightGBM] [Info] Start training from score -0.678848
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.795083	valid_0's pr_auc: 0.705784
# [40]	valid_0's auc: 0.80256	valid_0's pr_auc: 0.700218
# [60]	valid_0's auc: 0.803912	valid_0's pr_auc: 0.702322
# [80]	valid_0's auc: 0.804982	valid_0's pr_auc: 0.709069
# [100]	valid_0's auc: 0.806482	valid_0's pr_auc: 0.71071
# [120]	valid_0's auc: 0.806358	valid_0's pr_auc: 0.711783
# [140]	valid_0's auc: 0.806958	valid_0's pr_auc: 0.714117
# [160]	valid_0's auc: 0.806729	valid_0's pr_auc: 0.714856
# [180]	valid_0's auc: 0.80788	valid_0's pr_auc: 0.716262
# [200]	valid_0's auc: 0.809005	valid_0's pr_auc: 0.718995
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.793018	valid_0's pr_auc: 0.713778
# [40]	valid_0's auc: 0.79474	valid_0's pr_auc: 0.714559
# [60]	valid_0's auc: 0.797585	valid_0's pr_auc: 0.718049
# [80]	valid_0's auc: 0.79969	valid_0's pr_auc: 0.72197
# [100]	valid_0's auc: 0.801039	valid_0's pr_auc: 0.723893
# [120]	valid_0's auc: 0.801718	valid_0's pr_auc: 0.725403
# [140]	valid_0's auc: 0.803515	valid_0's pr_auc: 0.728912
# [160]	valid_0's auc: 0.80519	valid_0's pr_auc: 0.730584
# [180]	valid_0's auc: 0.806231	valid_0's pr_auc: 0.731238
# [200]	valid_0's auc: 0.80696	valid_0's pr_auc: 0.733787
# [220]	valid_0's auc: 0.807118	valid_0's pr_auc: 0.734072
# [240]	valid_0's auc: 0.807956	valid_0's pr_auc: 0.733142
# [260]	valid_0's auc: 0.808612	valid_0's pr_auc: 0.733173
# [280]	valid_0's auc: 0.809153	valid_0's pr_auc: 0.732647
# [300]	valid_0's auc: 0.809808	valid_0's pr_auc: 0.73395
# [320]	valid_0's auc: 0.809925	valid_0's pr_auc: 0.734659
# [340]	valid_0's auc: 0.810418	valid_0's pr_auc: 0.736446
# [360]	valid_0's auc: 0.810687	valid_0's pr_auc: 0.736023
# [380]	valid_0's auc: 0.81066	valid_0's pr_auc: 0.736355
# [400]	valid_0's auc: 0.810884	valid_0's pr_auc: 0.73726
# [420]	valid_0's auc: 0.811054	valid_0's pr_auc: 0.73774
# [440]	valid_0's auc: 0.811881	valid_0's pr_auc: 0.738861
# [460]	valid_0's auc: 0.812066	valid_0's pr_auc: 0.738982
# [480]	valid_0's auc: 0.812443	valid_0's pr_auc: 0.739897
# [500]	valid_0's auc: 0.81264	valid_0's pr_auc: 0.7398
# [520]	valid_0's auc: 0.8124	valid_0's pr_auc: 0.739457
# [540]	valid_0's auc: 0.81277	valid_0's pr_auc: 0.740044
# [560]	valid_0's auc: 0.812579	valid_0's pr_auc: 0.740342
# [580]	valid_0's auc: 0.812889	valid_0's pr_auc: 0.740433
# [600]	valid_0's auc: 0.812737	valid_0's pr_auc: 0.740252
# [620]	valid_0's auc: 0.813032	valid_0's pr_auc: 0.740379
# [640]	valid_0's auc: 0.812885	valid_0's pr_auc: 0.740864
# [660]	valid_0's auc: 0.813104	valid_0's pr_auc: 0.741564
# [680]	valid_0's auc: 0.812905	valid_0's pr_auc: 0.742124
# [700]	valid_0's auc: 0.812928	valid_0's pr_auc: 0.742221
# [720]	valid_0's auc: 0.812989	valid_0's pr_auc: 0.742328
# Early stopping, best iteration is:
# [629]	valid_0's auc: 0.813154	valid_0's pr_auc: 0.74058
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.817275076212649

# %%
# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.

encoder.fit(train_err['errcode'].astype('|S80'))
errcode_label = encoder.transform(train_err['errcode'].astype('|S80'))
train_err = pd.concat([train_err,pd.Series(errcode_label)],axis=1)
train_err.rename(columns = {0 : 'errcode_label'}, inplace = True)

# %%
errcode_label_ = train_err[['user_id','errcode_label']].values
errcode_check = np.zeros((train_user_number,len(train_err['errcode_label'].unique())))

for person_idx, ch in tqdm(errcode_label_):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    errcode_check[person_idx - train_user_id_min,ch - 1] += 1
errcode_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:47<00:00, 347135.61it/s]
# (15000, 2806)

# %%
# errcode를 모델에 적용
x_concat4 = np.concatenate((x_concat3, errcode_check), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러 + 에러코드

# %%
# 변수 이름 변경
# error  -> train_x
# problem-> train_y

train_x = x_concat4
train_y = problem
print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 2942)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=5, shuffle=True, random_state=150)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 100
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4064, number of negative: 7936
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24238
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 194
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.338667 -> initscore=-0.669242
# [LightGBM] [Info] Start training from score -0.669242
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.814044	valid_0's pr_auc: 0.720993
# [40]	valid_0's auc: 0.815765	valid_0's pr_auc: 0.721679
# [60]	valid_0's auc: 0.816988	valid_0's pr_auc: 0.723167
# [80]	valid_0's auc: 0.818262	valid_0's pr_auc: 0.725336
# [100]	valid_0's auc: 0.818716	valid_0's pr_auc: 0.726012
# [120]	valid_0's auc: 0.819472	valid_0's pr_auc: 0.728201
# [140]	valid_0's auc: 0.820318	valid_0's pr_auc: 0.727212
# [160]	valid_0's auc: 0.821708	valid_0's pr_auc: 0.728294
# [180]	valid_0's auc: 0.822562	valid_0's pr_auc: 0.730052
# [200]	valid_0's auc: 0.823277	valid_0's pr_auc: 0.730732
# [220]	valid_0's auc: 0.823984	valid_0's pr_auc: 0.731581
# [240]	valid_0's auc: 0.824717	valid_0's pr_auc: 0.730447
# [260]	valid_0's auc: 0.82517	valid_0's pr_auc: 0.729745
# [280]	valid_0's auc: 0.825582	valid_0's pr_auc: 0.729385
# [300]	valid_0's auc: 0.825898	valid_0's pr_auc: 0.729768
# [320]	valid_0's auc: 0.826301	valid_0's pr_auc: 0.733244
# [340]	valid_0's auc: 0.826834	valid_0's pr_auc: 0.735219
# [360]	valid_0's auc: 0.827098	valid_0's pr_auc: 0.735121
# [380]	valid_0's auc: 0.827492	valid_0's pr_auc: 0.736026
# [400]	valid_0's auc: 0.827622	valid_0's pr_auc: 0.737686
# [420]	valid_0's auc: 0.827675	valid_0's pr_auc: 0.738436
# [440]	valid_0's auc: 0.827887	valid_0's pr_auc: 0.738806
# [460]	valid_0's auc: 0.828062	valid_0's pr_auc: 0.739177
# [480]	valid_0's auc: 0.828289	valid_0's pr_auc: 0.739191
# [500]	valid_0's auc: 0.828511	valid_0's pr_auc: 0.739899
# [520]	valid_0's auc: 0.828654	valid_0's pr_auc: 0.739367
# [540]	valid_0's auc: 0.828849	valid_0's pr_auc: 0.739727
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.784677	valid_0's pr_auc: 0.706282
# [40]	valid_0's auc: 0.785816	valid_0's pr_auc: 0.707449
# [60]	valid_0's auc: 0.787334	valid_0's pr_auc: 0.71067
# [80]	valid_0's auc: 0.789598	valid_0's pr_auc: 0.712315
# [100]	valid_0's auc: 0.790879	valid_0's pr_auc: 0.713267
# [120]	valid_0's auc: 0.791646	valid_0's pr_auc: 0.711134
# [140]	valid_0's auc: 0.792458	valid_0's pr_auc: 0.712604
# [160]	valid_0's auc: 0.793505	valid_0's pr_auc: 0.712739
# [180]	valid_0's auc: 0.794539	valid_0's pr_auc: 0.715176
# [200]	valid_0's auc: 0.795608	valid_0's pr_auc: 0.715957
# [220]	valid_0's auc: 0.796742	valid_0's pr_auc: 0.718618
# [240]	valid_0's auc: 0.797452	valid_0's pr_auc: 0.717823
# [260]	valid_0's auc: 0.798065	valid_0's pr_auc: 0.718814
# [280]	valid_0's auc: 0.798206	valid_0's pr_auc: 0.718809
# [300]	valid_0's auc: 0.798114	valid_0's pr_auc: 0.718882
# [320]	valid_0's auc: 0.79833	valid_0's pr_auc: 0.720327
# [340]	valid_0's auc: 0.798633	valid_0's pr_auc: 0.719709
# [360]	valid_0's auc: 0.798683	valid_0's pr_auc: 0.720127
# [380]	valid_0's auc: 0.798786	valid_0's pr_auc: 0.719757
# [400]	valid_0's auc: 0.798986	valid_0's pr_auc: 0.72111
# [420]	valid_0's auc: 0.798917	valid_0's pr_auc: 0.720946
# [440]	valid_0's auc: 0.799076	valid_0's pr_auc: 0.721202
# [460]	valid_0's auc: 0.798931	valid_0's pr_auc: 0.721064
# [480]	valid_0's auc: 0.79885	valid_0's pr_auc: 0.72145
# [500]	valid_0's auc: 0.799012	valid_0's pr_auc: 0.721573
# [520]	valid_0's auc: 0.798947	valid_0's pr_auc: 0.721604
# Early stopping, best iteration is:
# [433]	valid_0's auc: 0.799224	valid_0's pr_auc: 0.721488
# ==========================================================
# [LightGBM] [Info] Number of positive: 3969, number of negative: 8031
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24008
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 196
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.330750 -> initscore=-0.704795
# [LightGBM] [Info] Start training from score -0.704795
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.80374	valid_0's pr_auc: 0.720256
# [40]	valid_0's auc: 0.807242	valid_0's pr_auc: 0.720879
# [60]	valid_0's auc: 0.80866	valid_0's pr_auc: 0.726563
# [80]	valid_0's auc: 0.810801	valid_0's pr_auc: 0.728929
# [100]	valid_0's auc: 0.813127	valid_0's pr_auc: 0.733653
# [120]	valid_0's auc: 0.815435	valid_0's pr_auc: 0.736955
# [140]	valid_0's auc: 0.817153	valid_0's pr_auc: 0.738109
# [160]	valid_0's auc: 0.818501	valid_0's pr_auc: 0.738698
# [180]	valid_0's auc: 0.819526	valid_0's pr_auc: 0.741411
# [200]	valid_0's auc: 0.820259	valid_0's pr_auc: 0.742163
# [220]	valid_0's auc: 0.82074	valid_0's pr_auc: 0.741601
# [240]	valid_0's auc: 0.821405	valid_0's pr_auc: 0.740439
# [260]	valid_0's auc: 0.821862	valid_0's pr_auc: 0.73986
# [280]	valid_0's auc: 0.822208	valid_0's pr_auc: 0.741383
# Early stopping, best iteration is:
# [198]	valid_0's auc: 0.820221	valid_0's pr_auc: 0.742396
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8219797356940377

# %%
from pycaret.classification import *

# %%
X = pd.DataFrame(x_concat4)
y = pd.DataFrame(problem)

# %%
X['problem'] = problem

# %%
clf = setup(data = X, target = 'problem')
# Out:
# <style  type="text/css" >
# </style><table id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row0_col1" class="data row0 col1" >3113</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row1_col1" class="data row1 col1" >problem</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row4_col1" class="data row4 col1" >(15000, 2943)</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row6_col1" class="data row6 col1" >665</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row7_col1" class="data row7 col1" >2277</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row11_col1" class="data row11 col1" >(10499, 1966)</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row12_col1" class="data row12 col1" >(4501, 1966)</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_42cb471e_5c67_11eb_ba1f_3497f6a285b1row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
best_5 = compare_models(sort = 'Accuracy', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1 th {
#           text-align: left;
#     }#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col0,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col3,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col6,#T_3bb998c1_5c6a_11 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col1,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col2,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col6,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col7,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col5,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col4,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row14_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row0_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row1_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row2_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row3_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row4_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row5_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row6_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row7_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row8_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row9_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row11_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row12_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row13_col8,#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3bb998c1_5c6a_11eb_a04d_3497f6a285b1level0_row0" class="row_heading level0 row0" >catboost</t

# %%
blended_5 = blend_models(estimator_list = best_5, fold = 10, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col0,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col1,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col2,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col3,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col4,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col5,#T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row10_col6{
#             background:  yellow;
#         }</style><table id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col0" class="data row0 col0" >0.8048</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col1" class="data row0 col1" >0.8465</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col2" class="data row0 col2" >0.5128</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col3" class="data row0 col3" >0.8411</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col4" class="data row0 col4" >0.6372</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col5" class="data row0 col5" >0.5141</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row0_col6" class="data row0 col6" >0.5436</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col0" class="data row1 col0" >0.7867</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col1" class="data row1 col1" >0.8330</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col2" class="data row1 col2" >0.4900</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col3" class="data row1 col3" >0.7926</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col4" class="data row1 col4" >0.6056</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col5" class="data row1 col5" >0.4703</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row1_col6" class="data row1 col6" >0.4959</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col0" class="data row2 col0" >0.7914</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col1" class="data row2 col1" >0.8161</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col2" class="data row2 col2" >0.4701</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col3" class="data row2 col3" >0.8333</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col4" class="data row2 col4" >0.6011</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col5" class="data row2 col5" >0.4743</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row2_col6" class="data row2 col6" >0.5100</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col0" class="data row3 col0" >0.7733</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col1" class="data row3 col1" >0.8000</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col2" class="data row3 col2" >0.4701</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col3" class="data row3 col3" >0.7604</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col4" class="data row3 col4" >0.5810</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col5" class="data row3 col5" >0.4372</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row3_col6" class="data row3 col6" >0.4610</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col0" class="data row4 col0" >0.8067</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col1" class="data row4 col1" >0.8454</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col2" class="data row4 col2" >0.5214</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col3" class="data row4 col3" >0.8394</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col4" class="data row4 col4" >0.6432</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col5" class="data row4 col5" >0.5204</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row4_col6" class="data row4 col6" >0.5481</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col0" class="data row5 col0" >0.7857</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col1" class="data row5 col1" >0.8108</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col2" class="data row5 col2" >0.5128</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col3" class="data row5 col3" >0.7692</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col4" class="data row5 col4" >0.6154</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col5" class="data row5 col5" >0.4750</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row5_col6" class="data row5 col6" >0.4937</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col0" class="data row6 col0" >0.7905</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col1" class="data row6 col1" >0.8267</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col2" class="data row6 col2" >0.4915</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col3" class="data row6 col3" >0.8084</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col4" class="data row6 col4" >0.6113</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col5" class="data row6 col5" >0.4793</td>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row6_col6" class="data row6 col6" >0.5071</td>
#             </tr>
#             <tr>
#                         <th id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1aa32fe1_5c6c_11eb_bfda_3497f6a285b1row7_co

# %%
pred_holdout = predict_model(blended_5)
# Out:
# <style  type="text/css" >
# </style><table id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col1" class="data row0 col1" >0.7934</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col2" class="data row0 col2" >0.8176</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col3" class="data row0 col3" >0.4976</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col4" class="data row0 col4" >0.8017</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col5" class="data row0 col5" >0.6141</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col6" class="data row0 col6" >0.4834</td>
#                         <td id="T_1be2c42e_5c6c_11eb_9abf_3497f6a285b1row0_col7" class="data row0 col7" >0.5090</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(blended_5)

# %%
best_2 = compare_models(sort = 'Accuracy', n_select = 2)

# %%
blended_2 = blend_models(estimator_list = best_2, fold = 10, method = 'soft')

# %%
pred_holdout = predict_model(blended_2)

# %%
test_err = pd.read_csv(PATH+'test_err_data.csv')

# %%
id_error = test_err[['user_id','errtype']].values
test_x = np.zeros((14999,42))
for person_idx, err in tqdm(id_error):
    test_x[person_idx - 30000,err - 1] += 1
test_x = test_x.reshape(test_x.shape[0],-1)
test = pd.DataFrame(data=test_x)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:50<00:00, 325830.06it/s]

# %%
## days의 변수로 만들기
test_err['datetime'] = test_err['time'].apply(make_datetime)
min_day = test_err.datetime.min().date()

test_err['days'] = test_err.loc[:,'datetime'].dt.date - min_day
test_err['days'] = test_err['days'].dt.days
display(test_err)
# Out:
#           user_id            time model_nm       fwver  errtype errcode  \
# 0           30000  20201101030227  model_1  04.16.3553       31       1
# 1           30000  20201101030227  model_1  04.16.3553       33       2
# 2           30000  20201101030228  model_1  04.16.3553       15       1
# 3           30000  20201101030256  model_1  04.16.3553       22       1
# 4           30000  20201101030300  model_1  04.16.3553       11       1
# ...           ...             ...      ...         ...      ...     ...
# 16532643    44998  20201130210050  model_1  04.16.3553       40       0
# 16532644    44998  20201130211831  model_1  04.16.3553       31       1
# 16532645    44998  20201130211832  model_1  04.16.3553       15       1
# 16532646    44998  20201130212259  model_1  04.16.3553       16       1
# 16532647    44998  20201130212316  model_1  04.16.3553       31       0
#
#                     datetime  days
# 0        2020-11-01 03:00:00     1
# 1        2020-11-01 03:00:00     1
# 2        2020-11-01 03:00:00     1
# 3        2020-11-01 03:00:00     1
# 4        2020-11-01 03:00:00     1
# ...                      ...   ...
# 16532643 2020-11-30 21:00:00    30
# 16532644 2020-11-30 21:00:00    30
# 16532645 2020-11-30 21:00:00    30
# 16532646 2020-11-30 21:00:00    30
# 16532647 2020-11-30 21:00:00    30
#
# [16532648 rows x 8 columns]

# %%
#적용하기
test_err['timeslot'] = test_err['time'].apply(time_encoding)

# %%
test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
encoder = LabelEncoder()
encoder.fit(test_err['fwver'].astype('|S80'))
labels_fwver = encoder.transform(test_err['fwver'].astype('|S80'))
test_err = pd.concat([test_err,pd.Series(labels_fwver)],axis=1)
test_err.rename(columns = {0 : 'labels_fwver'}, inplace = True)

# %%
fwver_label_test = test_err[['user_id','labels_fwver']].values
fwver_check_test = np.zeros((test_user_number,len(test_err['labels_fwver'].unique())))

for person_idx, ch in tqdm(fwver_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    fwver_check_test[person_idx - test_user_id_min,ch - 1] += 1
fwver_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:48<00:00, 337514.72it/s]
# (14999, 40)

# %%
days_label_test = test_err[['user_id','days']].values
days_check_test = np.zeros((test_user_number,max(test_err['days'])))

for person_idx, ch in tqdm(days_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    days_check_test[person_idx - test_user_id_min,ch-1] += 1
days_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:46<00:00, 354060.94it/s]
# (14999, 44)

# %%
len(test_err['labels_fwver'].unique())
# Out:
# 40

# %%
timeslot_label_test = test_err[['user_id','timeslot']].values
timeslot_check_test = np.zeros((test_user_number,len(test_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check_test[person_idx - test_user_id_min,ch - 1] += 1
timeslot_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:48<00:00, 342740.61it/s]
# (14999, 24)

# %%
timeslot_check_test
# Out:
# array([[  36.,   75.,  132., ...,  113.,   55.,   37.],
#        [   6.,    8.,    2., ...,    9.,   19.,   10.],
#        [  28.,   33.,    7., ...,   14.,   16.,   30.],
#        ...,
#        [  19.,   21.,   20., ...,  189.,   50.,   97.],
#        [ 921.,  813.,  782., ..., 1213., 1512., 1032.],
#        [  59.,  141.,   18., ...,   36.,   20.,   48.]])

# %%
### 드랍할거 하기

# %%
error_label_test = test_err[['user_id','errtype']].values
error_check_test = np.zeros((test_user_number,42))

for person_idx, err in tqdm(error_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error_check_test[person_idx - test_user_id_min,err - 1] += 1
error_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:47<00:00, 347159.61it/s]
# (14999, 42)

# %%
x_test1 = np.concatenate((fwver_check_test, days_check_test), axis=1) ## 펌웨어 버전 + 날짜 
x_test2 = np.concatenate((x_test1, timeslot_check_test), axis=1) ## 펌웨어 버전 + 날짜 +시간 
x_test3 = np.concatenate((x_test2, error_check_test), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러

# %%
#숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.

encoder.fit(test_err['errcode'].astype('|S80'))
errcode_label = encoder.transform(test_err['errcode'].astype('|S80'))
test_err = pd.concat([test_err,pd.Series(errcode_label)],axis=1)
test_err.rename(columns = {0 : 'errcode_label'}, inplace = True)

# %%
errcode_label_test = test_err[['user_id','errcode_label']].values
errcode_check_test = np.zeros((test_user_number,len(test_err['errcode_label'].unique())))

for person_idx, ch in tqdm(errcode_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    errcode_check_test[person_idx - test_user_id_min,ch - 1] += 1
errcode_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:46<00:00, 356607.92it/s]
# (14999, 2956)

# %%
# errcode를 모델에 적용
x_test4 = np.concatenate((x_test3, errcode_check_test), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러 + 에러코드

# %%
x_test4.shape
# Out:
# (14999, 3106)

# %%
X_test = pd.DataFrame(x_test4)

# %%
predictions = predict_model(final_model, data = X_test)

#pycaret에서는 score이 label을 맞출 확률이기때문에 output을 제출 양식에 맞게 바꿔줍니다
x = []
for i in range(len(predictions['Score'])):
  if predictions['Label'][i] =='1.0':
    x.append(predictions['Score'][i])
  else:
    x.append(1-predictions['Score'][i])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')
sample_submssion['problem'] = x
sample_submssion.to_csv("best_5.csv", index = False)

# %%
X = pd.DataFrame(x_concat3)
y = pd.DataFrame(problem)

# %%
X['problem'] = problem

# %%
clf = setup(data = X, target = 'problem')
# Out:
# <style  type="text/css" >
# </style><table id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row0_col1" class="data row0 col1" >4858</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row1_col1" class="data row1 col1" >problem</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row4_col1" class="data row4 col1" >(15000, 137)</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row6_col1" class="data row6 col1" >126</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row7_col1" class="data row7 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row11_col1" class="data row11 col1" >(10499, 134)</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row12_col1" class="data row12 col1" >(4501, 134)</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_dbeed0e5_5c74_11eb_af88_3497f6a285b1row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
best_5 = compare_models(sort = 'Accuracy', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1 th {
#           text-align: left;
#     }#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col0,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col3,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col6,#T_9ecea7e6_5c75_11 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col1,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col2,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col5,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col6,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col7,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col4,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row14_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row0_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row1_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row2_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row3_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row4_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row5_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row6_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row7_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row8_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row9_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row11_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row12_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row13_col8,#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ecea7e6_5c75_11eb_a03f_3497f6a285b1level0_row0" class="row_heading level0 row0" >catboost</t

# %%
blended_5 = blend_models(estimator_list = best_5, fold = 10, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col0,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col1,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col2,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col3,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col4,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col5,#T_33accb0a_5c76_11eb_9c24_3497f6a285b1row10_col6{
#             background:  yellow;
#         }</style><table id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col0" class="data row0 col0" >0.7810</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col1" class="data row0 col1" >0.8100</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col2" class="data row0 col2" >0.4533</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col3" class="data row0 col3" >0.8122</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col4" class="data row0 col4" >0.5818</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col5" class="data row0 col5" >0.4492</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row0_col6" class="data row0 col6" >0.4842</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col0" class="data row1 col0" >0.7895</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col1" class="data row1 col1" >0.8127</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col2" class="data row1 col2" >0.5071</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col3" class="data row1 col3" >0.7920</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col4" class="data row1 col4" >0.6183</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col5" class="data row1 col5" >0.4825</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row1_col6" class="data row1 col6" >0.5054</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col0" class="data row2 col0" >0.7857</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col1" class="data row2 col1" >0.8379</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col2" class="data row2 col2" >0.4533</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col3" class="data row2 col3" >0.8333</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col4" class="data row2 col4" >0.5872</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col5" class="data row2 col5" >0.4590</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row2_col6" class="data row2 col6" >0.4978</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col0" class="data row3 col0" >0.7819</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col1" class="data row3 col1" >0.8027</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col2" class="data row3 col2" >0.4731</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col3" class="data row3 col3" >0.7952</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col4" class="data row3 col4" >0.5933</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col5" class="data row3 col5" >0.4571</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row3_col6" class="data row3 col6" >0.4859</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col0" class="data row4 col0" >0.7971</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col1" class="data row4 col1" >0.8234</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col2" class="data row4 col2" >0.4887</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col3" class="data row4 col3" >0.8439</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col4" class="data row4 col4" >0.6190</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col5" class="data row4 col5" >0.4938</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row4_col6" class="data row4 col6" >0.5280</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col0" class="data row5 col0" >0.7933</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col1" class="data row5 col1" >0.8193</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col2" class="data row5 col2" >0.4774</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col3" class="data row5 col3" >0.8408</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col4" class="data row5 col4" >0.6090</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col5" class="data row5 col5" >0.4827</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row5_col6" class="data row5 col6" >0.5184</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col0" class="data row6 col0" >0.7981</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col1" class="data row6 col1" >0.8183</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col2" class="data row6 col2" >0.4944</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col3" class="data row6 col3" >0.8413</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col4" class="data row6 col4" >0.6228</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col5" class="data row6 col5" >0.4973</td>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row6_col6" class="data row6 col6" >0.5301</td>
#             </tr>
#             <tr>
#                         <th id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_33accb0a_5c76_11eb_9c24_3497f6a285b1row7_co

# %%
pred_holdout = predict_model(blended_5)
# Out:
# <style  type="text/css" >
# </style><table id="T_34042517_5c76_11eb_a401_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34042517_5c76_11eb_a401_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col1" class="data row0 col1" >0.7932</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col2" class="data row0 col2" >0.8159</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col3" class="data row0 col3" >0.4792</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col4" class="data row0 col4" >0.8069</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col5" class="data row0 col5" >0.6013</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col6" class="data row0 col6" >0.4736</td>
#                         <td id="T_34042517_5c76_11eb_a401_3497f6a285b1row0_col7" class="data row0 col7" >0.5029</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(blended_5)

# %%
X_test = pd.DataFrame(x_test3)

# %%
predictions = predict_model(final_model, data = X_test)

#pycaret에서는 score이 label을 맞출 확률이기때문에 output을 제출 양식에 맞게 바꿔줍니다
x = []
for i in range(len(predictions['Score'])):
  if predictions['Label'][i] =='1.0':
    x.append(predictions['Score'][i])
  else:
    x.append(1-predictions['Score'][i])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')
sample_submssion['problem'] = x
sample_submssion.to_csv("best_5.csv", index = False)

# %%
### 모형을 돌려본 결과 테스트와 트레인의 차원이 달라 예측값이 매우 낮게 발생함.
## 고로 차원이 비슷한 결과물 끼리 돌리기로 결정
x_concat_e = np.concatenate((timeslot_check, error), axis=1) ## 시간 + 에러
x_concat_elog = np.concatenate((np.log1p(timeslot_check), np.log1p(error)), axis=1)# 로그변환-시간 + 에러

# %%
# 변수 이름 변경
# error  -> train_x
# problem-> train_y

train_x = x_concat_e
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 66)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=10, shuffle=True, random_state=150)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 100
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4543, number of negative: 8957
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10767
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.336519 -> initscore=-0.678848
# [LightGBM] [Info] Start training from score -0.678848
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.792145	valid_0's pr_auc: 0.696888
# [40]	valid_0's auc: 0.793589	valid_0's pr_auc: 0.692737
# [60]	valid_0's auc: 0.796053	valid_0's pr_auc: 0.695539
# [80]	valid_0's auc: 0.797866	valid_0's pr_auc: 0.697197
# [100]	valid_0's auc: 0.797833	valid_0's pr_auc: 0.696824
# [120]	valid_0's auc: 0.798467	valid_0's pr_auc: 0.698885
# [140]	valid_0's auc: 0.799604	valid_0's pr_auc: 0.700916
# [160]	valid_0's auc: 0.800373	valid_0's pr_auc: 0.699223
# [180]	valid_0's auc: 0.802196	valid_0's pr_auc: 0.701259
# [200]	valid_0's auc: 0.80383	valid_0's pr_auc: 0.701725
# [220]	valid_0's auc: 0.805414	valid_0's pr_auc: 0.703877
# [240]	valid_0's auc: 0.806142	valid_0's pr_auc: 0.702955
# [260]	valid_0's auc: 0.807537	valid_0's pr_auc: 0.705641
# [280]	valid_0's auc: 0.808453	valid_0's pr_auc: 0.707323
# [300]	valid_0's auc: 0.809368	valid_0's pr_auc: 0.708732
# [320]	valid_0's auc: 0.809876	valid_0's pr_auc: 0.711403
# [340]	valid_0's auc: 0.810153	valid_0's pr_auc: 0.712735
# [360]	valid_0's auc: 0.810524	valid_0's pr_auc: 0.713584
# [380]	valid_0's auc: 0.811164	valid_0's pr_auc: 0.714634
# [400]	valid_0's auc: 0.81116	valid_0's pr_auc: 0.716046
# [420]	valid_0's auc: 0.811474	valid_0's pr_auc: 0.715792
# [440]	valid_0's auc: 0.811573	valid_0's pr_auc: 0.714824
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.798428	valid_0's pr_auc: 0.713385
# [40]	valid_0's auc: 0.801963	valid_0's pr_auc: 0.710938
# [60]	valid_0's auc: 0.805112	valid_0's pr_auc: 0.714561
# [80]	valid_0's auc: 0.807285	valid_0's pr_auc: 0.71536
# [100]	valid_0's auc: 0.809366	valid_0's pr_auc: 0.717524
# [120]	valid_0's auc: 0.810946	valid_0's pr_auc: 0.718067
# [140]	valid_0's auc: 0.812284	valid_0's pr_auc: 0.720026
# [160]	valid_0's auc: 0.813265	valid_0's pr_auc: 0.723594
# [180]	valid_0's auc: 0.814774	valid_0's pr_auc: 0.726272
# [200]	valid_0's auc: 0.8153	valid_0's pr_auc: 0.724373
# [220]	valid_0's auc: 0.816283	valid_0's pr_auc: 0.724199
# [240]	valid_0's auc: 0.81643	valid_0's pr_auc: 0.723947
# [260]	valid_0's auc: 0.817538	valid_0's pr_auc: 0.725144
# [280]	valid_0's auc: 0.817911	valid_0's pr_auc: 0.724145
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.81481	valid_0's pr_auc: 0.726369
# ==========================================================
# [LightGBM] [Info] Number of positive: 4473, number of negative: 9027
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10757
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.331333 -> initscore=-0.702161
# [LightGBM] [Info] Start training from score -0.702161
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.792968	valid_0's pr_auc: 0.715028
# [40]	valid_0's auc: 0.79314	valid_0's pr_auc: 0.713805
# [60]	valid_0's auc: 0.795422	valid_0's pr_auc: 0.717516
# [80]	valid_0's auc: 0.79595	valid_0's pr_auc: 0.718817
# [100]	valid_0's auc: 0.796847	valid_0's pr_auc: 0.719807
# [120]	valid_0's auc: 0.797661	valid_0's pr_auc: 0.720677
# [140]	valid_0's auc: 0.798717	valid_0's pr_auc: 0.72085
# [160]	valid_0's auc: 0.799934	valid_0's pr_auc: 0.721893
# [180]	valid_0's auc: 0.800164	valid_0's pr_auc: 0.720828
# [200]	valid_0's auc: 0.800546	valid_0's pr_auc: 0.719644
# [220]	valid_0's auc: 0.801539	valid_0's pr_auc: 0.718768
# [240]	valid_0's auc: 0.802031	valid_0's pr_auc: 0.717911
# [260]	valid_0's auc: 0.80251	valid_0's pr_auc: 0.718242
# Early stopping, best iteration is:
# [160]	valid_0's auc: 0.799934	valid_0's pr_auc: 0.721893
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8054116803869326

# %%
x_test_e = np.concatenate((timeslot_check_test, error_check_test), axis=1) ## 시간 + 에러

# %%
pred_y_list = []
for model in models:
    pred_y = model.predict(x_test_e)
    pred_y_list.append(pred_y.reshape(-1,1))
    
pred_ensemble = np.mean(pred_y_list, axis = 0)

# %%
pred_ensemble
# Out:
# array([[0.79977784],
#        [0.21867192],
#        [0.30318728],
#        ...,
#        [0.47421426],
#        [0.81242244],
#        [0.33513297]])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')

sample_submssion['problem'] = pred_ensemble.reshape(-1)

sample_submssion.to_csv("dacon_baseline.csv", index = False)
sample_submssion
# Out:
#        user_id   problem
# 0        30000  0.799778
# 1        30001  0.218672
# 2        30002  0.303187
# 3        30003  0.552933
# 4        30004  0.555206
# ...        ...       ...
# 14994    44994  0.343052
# 14995    44995  0.323713
# 14996    44996  0.474214
# 14997    44997  0.812422
# 14998    44998  0.335133
#
# [14999 rows x 2 columns]

# %%
# Out:
# array([[10000,     2],
#        [10000,     3],
#        [10000,     3],
#        ...,
#        [24999,    17],
#        [24999,    17],
#        [24999,    21]], dtype=int64)

# %%
## 로그 변환된 분석

train_x = x_concat_elog
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 66)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=10, shuffle=True, random_state=50)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 20
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4495, number of negative: 9005
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001310 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10750
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332963 -> initscore=-0.694814
# [LightGBM] [Info] Start training from score -0.694814
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.796425	valid_0's pr_auc: 0.711435
# Early stopping, best iteration is:
# [12]	valid_0's auc: 0.797252	valid_0's pr_auc: 0.71512
# ==========================================================
# [LightGBM] [Info] Number of positive: 4504, number of negative: 8996
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002448 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10773
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333630 -> initscore=-0.691814
# [LightGBM] [Info] Start training from score -0.691814
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.787864	valid_0's pr_auc: 0.699776
# Early stopping, best iteration is:
# [13]	valid_0's auc: 0.787642	valid_0's pr_auc: 0.700603
# ==========================================================
# [LightGBM] [Info] Number of positive: 4498, number of negative: 9002
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10780
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333185 -> initscore=-0.693814
# [LightGBM] [Info] Start training from score -0.693814
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.783938	valid_0's pr_auc: 0.697579
# Early stopping, best iteration is:
# [6]	valid_0's auc: 0.784436	valid_0's pr_auc: 0.699425
# ==========================================================
# [LightGBM] [Info] Number of positive: 4508, number of negative: 8992
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001237 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10787
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333926 -> initscore=-0.690482
# [LightGBM] [Info] Start training from score -0.690482
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.793478	valid_0's pr_auc: 0.69963
# Early stopping, best iteration is:
# [8]	valid_0's auc: 0.794119	valid_0's pr_auc: 0.703245
# ==========================================================
# [LightGBM] [Info] Number of positive: 4515, number of negative: 8985
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002480 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10763
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334444 -> initscore=-0.688151
# [LightGBM] [Info] Start training from score -0.688151
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.794027	valid_0's pr_auc: 0.704689
# [40]	valid_0's auc: 0.793527	valid_0's pr_auc: 0.696475
# Early stopping, best iteration is:
# [26]	valid_0's auc: 0.794175	valid_0's pr_auc: 0.705248
# ==========================================================
# [LightGBM] [Info] Number of positive: 4516, number of negative: 8984
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001641 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10760
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334519 -> initscore=-0.687819
# [LightGBM] [Info] Start training from score -0.687819
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.77946	valid_0's pr_auc: 0.680204
# [40]	valid_0's auc: 0.781081	valid_0's pr_auc: 0.666986
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.780752	valid_0's pr_auc: 0.680856
# ==========================================================
# [LightGBM] [Info] Number of positive: 4519, number of negative: 8981
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10754
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334741 -> initscore=-0.686821
# [LightGBM] [Info] Start training from score -0.686821
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.799697	valid_0's pr_auc: 0.693197
# Early stopping, best iteration is:
# [9]	valid_0's auc: 0.797781	valid_0's pr_auc: 0.714281
# ==========================================================
# [LightGBM] [Info] Number of positive: 4481, number of negative: 9019
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002998 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10745
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.331926 -> initscore=-0.699487
# [LightGBM] [Info] Start training from score -0.699487
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.79028	valid_0's pr_auc: 0.710913
# [40]	valid_0's auc: 0.793682	valid_0's pr_auc: 0.704755
# Early stopping, best iteration is:
# [36]	valid_0's auc: 0.792379	valid_0's pr_auc: 0.712649
# ==========================================================
# [LightGBM] [Info] Number of positive: 4490, number of negative: 9010
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001229 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10779
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332593 -> initscore=-0.696482
# [LightGBM] [Info] Start training from score -0.696482
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.79342	valid_0's pr_auc: 0.720686
# [40]	valid_0's auc: 0.797673	valid_0's pr_auc: 0.720976
# [60]	valid_0's auc: 0.79952	valid_0's pr_auc: 0.721685
# Early stopping, best iteration is:
# [52]	valid_0's auc: 0.799295	valid_0's pr_auc: 0.723116
# ==========================================================
# [LightGBM] [Info] Number of positive: 4474, number of negative: 9026
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001249 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10764
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.331407 -> initscore=-0.701826
# [LightGBM] [Info] Start training from score -0.701826
# Training until validation scores don't improve for 20 rounds
# [20]	valid_0's auc: 0.793021	valid_0's pr_auc: 0.723701
# Early stopping, best iteration is:
# [4]	valid_0's auc: 0.796225	valid_0's pr_auc: 0.72264
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.7924054448591031

# %%
x_test_elog = np.concatenate((np.log1p(timeslot_check_test), np.log1p(error_check_test)), axis=1) ## 로그변환-시간 + 에러

# %%
pred_y_list = []
for model in models:
    pred_y = model.predict(x_test_elog)
    pred_y_list.append(pred_y.reshape(-1,1))
    
pred_ensemble = np.mean(pred_y_list, axis = 0)

# %%
pred_ensemble
# Out:
# array([[0.40775712],
#        [0.30880252],
#        [0.32820013],
#        ...,
#        [0.35218885],
#        [0.4262475 ],
#        [0.32975762]])

# %%
plot(timeslot_check_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-5bad91831643> in <module>
# ----> 1 plot(timeslot_check_test)
#
# NameError: name 'plot' is not defined

# %%
plt.plot(np.log1p(timeslot_check_test))
# Out:
# [<matplotlib.lines.Line2D at 0x1aa27a6b220>,
#  <matplotlib.lines.Line2D at 0x1aa27a6b5e0>,
#  <matplotlib.lines.Line2D at 0x1aa27a6bac0>,
#  <matplotlib.lines.Line2D at 0x1aa27a6bfa0>,
#  <matplotlib.lines.Line2D at 0x1aa27a6b0a0>,
#  <matplotlib.lines.Line2D at 0x1aa27a6b190>,
#  <matplotlib.lines.Line2D at 0x1aa27a6b1f0>,
#  <matplotlib.lines.Line2D at 0x1aa27a6b640>,
#  <matplotlib.lines.Line2D at 0x1a86833af10>,
#  <matplotlib.lines.Line2D at 0x1a86833a7c0>,
#  <matplotlib.lines.Line2D at 0x1a87b612fa0>,
#  <matplotlib.lines.Line2D at 0x1a86833a640>,
#  <matplotlib.lines.Line2D at 0x1a86833ad90>,
#  <matplotlib.lines.Line2D at 0x1a86833a550>,
#  <matplotlib.lines.Line2D at 0x1a86833ae20>,
#  <matplotlib.lines.Line2D at 0x1a86833aeb0>,
#  <matplotlib.lines.Line2D at 0x1a86833a8b0>,
#  <matplotlib.lines.Line2D at 0x1a86833a2b0>,
#  <matplotlib.lines.Line2D at 0x1a86833a580>,
#  <matplotlib.lines.Line2D at 0x1a86833ad00>,
#  <matplotlib.lines.Line2D at 0x1a86833ae50>,
#  <matplotlib.lines.Line2D at 0x1a86833a9a0>,
#  <matplotlib.lines.Line2D at 0x1a86833a280>,
#  <matplotlib.lines.Line2D at 0x1a86833a0d0>]

# %%
plt.plot(error_check_test)
# Out:
# [<matplotlib.lines.Line2D at 0x1a8c25f73a0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d40760>,
#  <matplotlib.lines.Line2D at 0x1a8b9d405e0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d40460>,
#  <matplotlib.lines.Line2D at 0x1a8b9d402e0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d40be0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d40df0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d40eb0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d260d0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26cd0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d45f40>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26250>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26850>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26d00>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26a00>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26700>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26400>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26100>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26fa0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26b20>,
#  <matplotlib.lines.Line2D at 0x1a8b9d269a0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26820>,
#  <matplotlib.lines.Line2D at 0x1a8b9d266a0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26520>,
#  <matplotlib.lines.Line2D at 0x1a8b9d263a0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26220>,
#  <matplotlib.lines.Line2D at 0x1a8b9d261f0>,
#  <matplotlib.lines.Line2D at 0x1a8b9d26070>,
#  <matplotlib.lines.Line2D at 0x1a8792f0e50>,
#  <matplotlib.lines.Line2D at 0x1a8792f0790>,
#  <matplotlib.lines.Line2D at 0x1a8792f0910>,
#  <matplotlib.lines.Line2D at 0x1a8792f0610>,
#  <matplotlib.lines.Line2D at 0x1a8792f09d0>,
#  <matplotlib.lines.Line2D at 0x1a8792f0e80>,
#  <matplotlib.lines.Line2D at 0x1a8792f0b80>,
#  <matplotlib.lines.Line2D at 0x1a8792f0880>,
#  <matplotlib.lines.Line2D at 0x1a8792f0580>,
#  <matplotlib.lines.Line2D at 0x1a8792f0280>,
#  <matplotlib.lines.Line2D at 0x1a8792f0d30>,
#  <matplotlib.lines.Line2D at 0x1a8792f0f70>,
#  <matplotlib.lines.Line2D at 0x1a8792f0a60>,
#  <matplotlib.lines.Line2D at 0x1a8792f08e0>]
