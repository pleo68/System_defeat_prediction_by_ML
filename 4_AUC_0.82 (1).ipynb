# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import random
import lightgbm as lgb
import re
import seaborn as sns
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings(action='ignore')

# 필요한 함수 정의
def make_datetime(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    year  = int(x[:4])
    month = int(x[4:6])
    day   = int(x[6:8])
    hour  = int(x[8:10])
    #mim  = int(x[10:12])
    #sec  = int(x[12:])
    return dt.datetime(year, month, day, hour)

def string2num(x):
    # (,)( )과 같은 불필요한 데이터 정제
    x = re.sub(r"[^0-9]+", '', str(x))
    if x =='':
        return 0
    else:
        return int(x)


PATH = './data/'

# %%
train_err  = pd.read_csv(PATH+'train_err_data.csv')
train_quality  = pd.read_csv(PATH+'train_quality_data.csv')
train_problem  = pd.read_csv(PATH+'train_problem_data.csv')

test_err  = pd.read_csv(PATH+'test_err_data.csv')
test_quality  = pd.read_csv(PATH+'test_quality_data.csv')

# %%
# train_quality 데이터에 대해서 strin2num 함수 적용 int로 변환
train_quality['quality_10'] = train_quality['quality_10'].apply(string2num)

# %%
# quality 10 에 대해서 행의 평균값에 따라 분류
q10_mean = train_quality.groupby('user_id').quality_10.mean()

# %%
# 저장
filter1500_train = q10_mean[q10_mean >= 1500]
filter200_train = q10_mean[(q10_mean >= 200) & (q10_mean <= 1500)]
filter50_train = q10_mean[(q10_mean >= 50) & (q10_mean <= 200)]

# %%
# 인덱스값
filter1500_train.index
filter200_train.index
filter50_train.index
# Out:
# Int64Index([10049, 10056, 10072, 10104, 10110, 10113, 10152, 10154, 10167,
#             10236,
#             ...
#             24786, 24811, 24844, 24845, 24874, 24875, 24888, 24951, 24953,
#             24985],
#            dtype='int64', name='user_id', length=469)

# %%
# 인덱스 리스트 저장
q10train1500_list=[x for x in filter1500_train.index]
q10train200_list=[x for x in filter200_train.index]
q10train50_list=[x for x in filter50_train.index]

# %%
# 넘파이로 인덱싱 1 과 0 으로 표시
q10train_check = np.zeros((15000,1)) # 15000 아이디에 대해서 0 열 만들기

for idx in range(15000):
    if np.isin(idx+10000, [q10train1500_list]): # 10000부터 아이디가 시작하므로
        q10train_check[idx] = 3 #인덱스 리스트에 있으면 1 지정
        
for idx in range(15000):
    if np.isin(idx+10000, [q10train200_list]):
        q10train_check[idx] = 2

for idx in range(15000):
    if np.isin(idx+10000, [q10train50_list]):
        q10train_check[idx] = 1
        
q10train_check.shape
# quality 10 데이터에서 대해서 1500 / 200 / 50 을 기준으로 인코딩하였음

# %%
##시간별 데이터 만드는 코딩
def time_encoding(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    day   = int(x[6:8])
    hour  = int(x[8:10])
    y = day*100 + hour
    for i in range(30):
        if y == (i+1)*100:
            return 0
        if y == (i+1)*100 + 1:
            return 1
        if y == (i+1)*100 + 2:
            return 2
        if y == (i+1)*100 + 3:
            return 3
        if y == (i+1)*100 + 4:
            return 4
        if y == (i+1)*100 + 5:
            return 5
        if y == (i+1)*100 + 6:
            return 6
        if y == (i+1)*100 + 7:
            return 7
        if y == (i+1)*100 + 8:
            return 8
        if y == (i+1)*100 + 9:
            return 9
        if y == (i+1)*100 + 10:
            return 10
        if y == (i+1)*100 + 11:
            return 11
        if y == (i+1)*100 + 12:
            return 12
        if y == (i+1)*100 + 13:
            return 13
        if y == (i+1)*100 + 14:
            return 14
        if y == (i+1)*100 + 15:
            return 15
        if y == (i+1)*100 + 16:
            return 16
        if y == (i+1)*100 + 17:
            return 17
        if y == (i+1)*100 + 18:
            return 18
        if y == (i+1)*100 + 19:
            return 19
        if y == (i+1)*100 + 20:
            return 20
        if y == (i+1)*100 + 21:
            return 21
        if y == (i+1)*100 + 22:
            return 22
        if y == (i+1)*100 + 23:
            return 23
        if day == 31: # 10월 31일 23:59의 경우
            return 0

# %%
##날짜로 변환하는 함수
def day_encoding(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    month = int(x[4:6])
    day   = int(x[6:8])
    return month * 100 + day

# %%
def weekday_encoding(x): #월 / 주중 / 주말로 구분하는 코드
    monday_list = [1102, 1109, 1116, 1123, 1130, 1214]
    tuesday_list = [1103, 1110, 1117, 1124, 1201]
    wendesday_list = [1104, 1111, 1118, 1125, 1202, 1209]
    thursday_list = [1105, 1112, 1119, 1126, 1203]
    friday_list = [1106, 1113, 1120, 1127, 1204, 1211]
    saturday_list = [1205, 1031, 1107, 1114, 1121, 1128]
    sunday_list = [1101, 1108, 1115, 1122, 1129]
    if np.isin(x, monday_list): 
        return 0
    if np.isin(x, tuesday_list):
        return 1
    if np.isin(x, wendesday_list):
        return 2
    if np.isin(x, thursday_list):
        return 3
    if np.isin(x, friday_list):
        return 4
    if np.isin(x, saturday_list):
        return 5
    else:
        return 6

# %%
train_user_id_max = 24999
train_user_id_min = 10000
train_user_number = 15000

# %%
#시간 별로 나누기
train_err['timeslot'] = train_err['time'].apply(time_encoding)
train_err['day'] = train_err['time'].apply(day_encoding)
train_err['week'] = train_err['day'].apply(weekday_encoding)

# %%
# 요일별로 타임라벨링 하기 넘파이 활용
week_label = train_err[['user_id','week']].values
week_check = np.zeros((train_user_number,len(train_err['week'].unique())))

for person_idx, ch in tqdm(week_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    week_check[person_idx - train_user_id_min,ch - 1] += 1
week_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:49<00:00, 336854.45it/s]
# (15000, 7)

# %%
# 시간별로 타임라벨링 하기 넘파이 활용
timeslot_label = train_err[['user_id','timeslot']].values
timeslot_check = np.zeros((train_user_number,len(train_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check[person_idx - train_user_id_min,ch - 1] += 1
timeslot_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:50<00:00, 329430.98it/s]
# (15000, 24)

# %%
id_error = train_err[['user_id','errtype']].values
error = np.zeros((train_user_number,42))

for person_idx, err in tqdm(id_error):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error[person_idx - train_user_id_min,err - 1] += 1
error.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:49<00:00, 335207.30it/s]
# (15000, 42)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
### 모델명에 대해서 라벨 인코딩 진행
encoder = LabelEncoder()
encoder.fit(train_err['model_nm'].astype('|S80')) ## object 변수이므로 str 변수로 변환
labels_model = encoder.transform(train_err['model_nm'].astype('|S80'))
train_err = pd.concat([train_err,pd.Series(labels_model)],axis=1)
train_err.rename(columns = {0 : 'labels_model'}, inplace = True)

# %%
model_label = train_err[['user_id','labels_model']].values
model_nm = np.zeros((train_user_number,9))

for person_idx, ch in tqdm(model_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    model_nm[person_idx - train_user_id_min,ch - 1] += 1
model_nm_ = (model_nm > 0).astype(int) #0보다 큰 데이터는 그냥 전부 1로 변경
model_nm_.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:48<00:00, 338516.05it/s]
# (15000, 9)

# %%
# 분석에 활용하도록 넘파이 데이터 결합
x1 = np.concatenate((error, timeslot_check), axis=1) ## 에러 + 시간 
x2 = np.concatenate((x1, model_nm_), axis=1) ## 에러 + 시간 + 모델
x3 = np.concatenate((x2, week_check), axis=1) ## 에러 + 시간 + 모델 + 요일
x4 = np.concatenate((x3, q10train_check), axis=1) ## 에러 + 시간 + 모델 + 요일 + 퀄리티10

# %%
# Y 데이터 만들기
train_prob = pd.read_csv(PATH+'train_problem_data.csv')
problem = np.zeros(15000)
# error와 동일한 방법으로 person_idx - 10000 위치에 
# person_idx의 problem이 한 번이라도 발생했다면 1
# 없다면 0
problem[train_prob.user_id.unique()-10000] = 1 
problem.shape
# Out:
# (15000,)

# %%
# 변수 이름 변경
# x3  -> train_x
# problem-> train_y

train_x = x4
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 83)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=10, shuffle=True, random_state=150)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 100
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4543, number of negative: 8957
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001944 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12574
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.336519 -> initscore=-0.678848
# [LightGBM] [Info] Start training from score -0.678848
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.798098	valid_0's pr_auc: 0.705138
# [40]	valid_0's auc: 0.801451	valid_0's pr_auc: 0.709018
# [60]	valid_0's auc: 0.802727	valid_0's pr_auc: 0.709252
# [80]	valid_0's auc: 0.803864	valid_0's pr_auc: 0.710068
# [100]	valid_0's auc: 0.804924	valid_0's pr_auc: 0.711959
# [120]	valid_0's auc: 0.805857	valid_0's pr_auc: 0.715664
# [140]	valid_0's auc: 0.806436	valid_0's pr_auc: 0.717272
# [160]	valid_0's auc: 0.807257	valid_0's pr_auc: 0.717577
# [180]	valid_0's auc: 0.809104	valid_0's pr_auc: 0.719506
# [200]	valid_0's auc: 0.810335	valid_0's pr_auc: 0.720261
# [220]	valid_0's auc: 0.811306	valid_0's pr_auc: 0.718684
# [240]	valid_0's auc: 0.812381	valid_0's pr_auc: 0.72067
# [260]	valid_0's auc: 0.813568	valid_0's pr_auc: 0.722417
# [280]	valid_0's auc: 0.814672	valid_0's pr_auc: 0.722575
# [300]	valid_0's auc: 0.815272	valid_0's pr_auc: 0.725223
# [320]	valid_0's auc: 0.815641	valid_0's pr_auc: 0.727352
# [340]	valid_0's auc: 0.816094	valid_0's pr_auc: 0.728528
# [360]	valid_0's auc: 0.816654	valid_0's pr_auc: 0.731017
# [380]	valid_0's auc: 0.817021	valid_0's pr_auc: 0.732712
# [400]	valid_0's auc: 0.816931	valid_0's pr_auc: 0.733314
# [420]	valid_0's auc: 0.817082	valid_0's pr_auc: 0.733454
# [440]	valid_0's auc: 0.816816	valid_0's pr_auc: 0.733085
# [460]	valid_0's auc: 0.816765	valid_0's pr_auc: 0.732661
# [480]	valid_0's auc: 0.816839	valid_0's pr_auc: 0.731838
# Early stopping, best iteration is:
# [390]	valid_0's auc: 0.817164	valid_0's pr_auc: 0.733377
# ==========================================================
# [LightGBM] [Info] Number of positive: 4521, number of negative: 8979
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12577
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334889 -> initscore=-0.686155
# [LightGBM] [Info] Start training from score -0.686155
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.800952	valid_0's pr_auc: 0.700489
# [40]	valid_0's auc: 0.802174	valid_0's pr_auc: 0.70528
# [60]	valid_0's auc: 0.802484	valid_0's pr_auc: 0.704165
# [80]	valid_0's auc: 0.804486	valid_0's pr_auc: 0.709111
# [100]	valid_0's auc: 0.805938	valid_0's pr_auc: 0.709992
# [120]	valid_0's auc: 0.806995	valid_0's pr_auc: 0.709801
# [140]	valid_0's auc: 0.808393	valid_0's pr_auc: 0.709862
# [160]	valid_0's auc: 0.809396	valid_0's pr_auc: 0.710779
# [180]	valid_0's auc: 0.810022	valid_0's pr_auc: 0.711891
# [200]	valid_0's auc: 0.810889	valid_0's pr_auc: 0.713074
# [220]	valid_0's auc: 0.81134	valid_0's pr_auc: 0.713745
# [240]	valid_0's auc: 0.8123	valid_0's pr_auc: 0.717021
# [260]	valid_0's auc: 0.812875	valid_0's pr_auc: 0.719474
# [280]	valid_0's auc: 0.813382	valid_0's pr_auc: 0.719035
# [300]	valid_0's auc: 0.813307	valid_0's pr_auc: 0.719936
# [320]	valid_0's auc: 0.813335	valid_0's pr_auc: 0.719622
# [340]	valid_0's auc: 0.813634	valid_0's pr_auc: 0.720452
# [360]	valid_0's auc: 0.813793	valid_0's pr_auc: 0.720668
# [380]	valid_0's auc: 0.813865	valid_0's pr_auc: 0.722649
# [400]	valid_0's auc: 0.814104	valid_0's pr_auc: 0.724083
# [420]	valid_0's auc: 0.814057	valid_0's pr_auc: 0.724564
# [440]	valid_0's auc: 0.814194	valid_0's pr_auc: 0.725094
# [460]	valid_0's auc: 0.814223	valid_0's pr_auc: 0.725594
# [480]	valid_0's auc: 0.814235	valid_0's pr_auc: 0.726507
# [500]	valid_0's auc: 0.814378	valid_0's pr_auc: 0.726751
# [520]	valid_0's auc: 0.814572	valid_0's pr_auc: 0.727536
# [540]	valid_0's auc: 0.814251	valid_0's pr_auc: 0.726731
# [560]	valid_0's auc: 0.814059	valid_0's pr_auc: 0.726779
# [580]	valid_0's auc: 0.814143	valid_0's pr_auc: 0.726926
# [600]	valid_0's auc: 0.814108	valid_0's pr_auc: 0.72729
# [620]	valid_0's auc: 0.81409	valid_0's pr_auc: 0.726745
# Early stopping, best iteration is:
# [520]	valid_0's auc: 0.814572	valid_0's pr_auc: 0.727536
# ==========================================================
# [LightGBM] [Info] Number of positive: 4502, number of negative: 8998
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002850 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12574
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333481 -> initscore=-0.692481
# [LightGBM] [Info] Start training from score -0.692481
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.788151	valid_0's pr_auc: 0.677798
# [40]	valid_0's auc: 0.790403	valid_0's pr_auc: 0.680519
# [60]	valid_0's auc: 0.794816	valid_0's pr_auc: 0.684932
# [80]	valid_0's auc: 0.796966	valid_0's pr_auc: 0.693296
# [100]	valid_0's auc: 0.798467	valid_0's pr_auc: 0.69633
# [120]	valid_0's auc: 0.800116	valid_0's pr_auc: 0.699696
# [140]	valid_0's auc: 0.80122	valid_0's pr_auc: 0.701055
# [160]	valid_0's auc: 0.802039	valid_0's pr_auc: 0.704762
# [180]	valid_0's auc: 0.803586	valid_0's pr_auc: 0.710273
# [200]	valid_0's auc: 0.805062	valid_0's pr_auc: 0.712966
# [220]	valid_0's auc: 0.805671	valid_0's pr_auc: 0.715271
# [240]	valid_0's auc: 0.806044	valid_0's pr_auc: 0.715311
# [260]	valid_0's auc: 0.806881	valid_0's pr_auc: 0.716499
# [280]	valid_0's auc: 0.807216	valid_0's pr_auc: 0.715336
# [300]	valid_0's auc: 0.807613	valid_0's pr_auc: 0.716534
# [320]	valid_0's auc: 0.807876	valid_0's pr_auc: 0.715924
# [340]	valid_0's auc: 0.808377	valid_0's pr_auc: 0.713822
# [360]	valid_0's auc: 0.808105	valid_0's pr_auc: 0.713014
# [380]	valid_0's auc: 0.807898	valid_0's pr_auc: 0.713173
# [400]	valid_0's auc: 0.807435	valid_0's pr_auc: 0.71384
# Early stopping, best iteration is:
# [307]	valid_0's auc: 0.807785	valid_0's pr_auc: 0.717833
# ==========================================================
# [LightGBM] [Info] Number of positive: 4507, number of negative: 8993
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12580
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333852 -> initscore=-0.690815
# [LightGBM] [Info] Start training from score -0.690815
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.814424	valid_0's pr_auc: 0.713251
# [40]	valid_0's auc: 0.815454	valid_0's pr_auc: 0.716621
# [60]	valid_0's auc: 0.817147	valid_0's pr_auc: 0.719171
# [80]	valid_0's auc: 0.820639	valid_0's pr_auc: 0.727049
# [100]	valid_0's auc: 0.822861	valid_0's pr_auc: 0.732131
# [120]	valid_0's auc: 0.824327	valid_0's pr_auc: 0.734426
# [140]	valid_0's auc: 0.826523	valid_0's pr_auc: 0.736326
# [160]	valid_0's auc: 0.828116	valid_0's pr_auc: 0.735188
# [180]	valid_0's auc: 0.829115	valid_0's pr_auc: 0.738703
# [200]	valid_0's auc: 0.830265	valid_0's pr_auc: 0.741908
# [220]	valid_0's auc: 0.830638	valid_0's pr_auc: 0.742159
# [240]	valid_0's auc: 0.831611	valid_0's pr_auc: 0.740307
# [260]	valid_0's auc: 0.832098	valid_0's pr_auc: 0.737637
# [280]	valid_0's auc: 0.832753	valid_0's pr_auc: 0.73815
# [300]	valid_0's auc: 0.833138	valid_0's pr_auc: 0.740548
# Early stopping, best iteration is:
# [219]	valid_0's auc: 0.830664	valid_0's pr_auc: 0.74248
# ==========================================================
# [LightGBM] [Info] Number of positive: 4495, number of negative: 9005
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12572
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332963 -> initscore=-0.694814
# [LightGBM] [Info] Start training from score -0.694814
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.805465	valid_0's pr_auc: 0.7272
# [40]	valid_0's auc: 0.811861	valid_0's pr_auc: 0.73311
# [60]	valid_0's auc: 0.814111	valid_0's pr_auc: 0.73568
# [80]	valid_0's auc: 0.816935	valid_0's pr_auc: 0.738889
# [100]	valid_0's auc: 0.819005	valid_0's pr_auc: 0.743229
# [120]	valid_0's auc: 0.820917	valid_0's pr_auc: 0.748761
# [140]	valid_0's auc: 0.822038	valid_0's pr_auc: 0.749754
# [160]	valid_0's auc: 0.822646	valid_0's pr_auc: 0.749045
# [180]	valid_0's auc: 0.823953	valid_0's pr_auc: 0.749053
# [200]	valid_0's auc: 0.825187	valid_0's pr_auc: 0.749575
# [220]	valid_0's auc: 0.825928	valid_0's pr_auc: 0.749435
# [240]	valid_0's auc: 0.827227	valid_0's pr_auc: 0.751264
# [260]	valid_0's auc: 0.828051	valid_0's pr_auc: 0.752745
# [280]	valid_0's auc: 0.82902	valid_0's pr_auc: 0.754778
# [300]	valid_0's auc: 0.829281	valid_0's pr_auc: 0.753711
# [320]	valid_0's auc: 0.830015	valid_0's pr_auc: 0.754207
# [340]	valid_0's auc: 0.83026	valid_0's pr_auc: 0.754391
# [360]	valid_0's auc: 0.830638	valid_0's pr_auc: 0.754202
# [380]	valid_0's auc: 0.830698	valid_0's pr_auc: 0.755572
# [400]	valid_0's auc: 0.830867	valid_0's pr_auc: 0.755383
# [420]	valid_0's auc: 0.830861	valid_0's pr_auc: 0.753469
# [440]	valid_0's auc: 0.831331	valid_0's pr_auc: 0.753718
# [460]	valid_0's auc: 0.831733	valid_0's pr_auc: 0.754091
# Early stopping, best iteration is:
# [378]	valid_0's auc: 0.830718	valid_0's pr_auc: 0.755747
# ==========================================================
# [LightGBM] [Info] Number of positive: 4489, number of negative: 9011
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001473 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12564
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332519 -> initscore=-0.696816
# [LightGBM] [Info] Start training from score -0.696816
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.801935	valid_0's pr_auc: 0.725859
# [40]	valid_0's auc: 0.803153	valid_0's pr_auc: 0.72747
# [60]	valid_0's auc: 0.804733	valid_0's pr_auc: 0.729052
# [80]	valid_0's auc: 0.804703	valid_0's pr_auc: 0.728961
# [100]	valid_0's auc: 0.805874	valid_0's pr_auc: 0.731081
# [120]	valid_0's auc: 0.806804	valid_0's pr_auc: 0.736383
# [140]	valid_0's auc: 0.808003	valid_0's pr_auc: 0.737398
# [160]	valid_0's auc: 0.80808	valid_0's pr_auc: 0.739319
# [180]	valid_0's auc: 0.808234	valid_0's pr_auc: 0.740543
# [200]	valid_0's auc: 0.808954	valid_0's pr_auc: 0.74134
# [220]	valid_0's auc: 0.809442	valid_0's pr_auc: 0.742045
# [240]	valid_0's auc: 0.810075	valid_0's pr_auc: 0.743165
# [260]	valid_0's auc: 0.811201	valid_0's pr_auc: 0.744735
# [280]	valid_0's auc: 0.811856	valid_0's pr_auc: 0.745764
# [300]	valid_0's auc: 0.812709	valid_0's pr_auc: 0.74607
# [320]	valid_0's auc: 0.813221	valid_0's pr_auc: 0.745673
# [340]	valid_0's auc: 0.813678	valid_0's pr_auc: 0.746965
# [360]	valid_0's auc: 0.813629	valid_0's pr_auc: 0.747168
# [380]	valid_0's auc: 0.813936	valid_0's pr_auc: 0.747782
# [400]	valid_0's auc: 0.814272	valid_0's pr_auc: 0.74757
# [420]	valid_0's auc: 0.814584	valid_0's pr_auc: 0.747683
# [440]	valid_0's auc: 0.814681	valid_0's pr_auc: 0.746757
# [460]	valid_0's auc: 0.815068	valid_0's pr_auc: 0.746958
# [480]	valid_0's auc: 0.815061	valid_0's pr_auc: 0.746678
# Early stopping, best iteration is:
# [389]	valid_0's auc: 0.814045	valid_0's pr_auc: 0.747978
# ==========================================================
# [LightGBM] [Info] Number of positive: 4466, number of negative: 9034
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12542
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.330815 -> initscore=-0.704502
# [LightGBM] [Info] Start training from score -0.704502
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.775194	valid_0's pr_auc: 0.681439
# [40]	valid_0's auc: 0.776755	valid_0's pr_auc: 0.684054
# [60]	valid_0's auc: 0.781667	valid_0's pr_auc: 0.687926
# [80]	valid_0's auc: 0.783625	valid_0's pr_auc: 0.691841
# [100]	valid_0's auc: 0.784616	valid_0's pr_auc: 0.691516
# [120]	valid_0's auc: 0.785658	valid_0's pr_auc: 0.700504
# [140]	valid_0's auc: 0.786501	valid_0's pr_auc: 0.703109
# [160]	valid_0's auc: 0.786686	valid_0's pr_auc: 0.706577
# [180]	valid_0's auc: 0.787029	valid_0's pr_auc: 0.710498
# [200]	valid_0's auc: 0.788704	valid_0's pr_auc: 0.714088
# [220]	valid_0's auc: 0.789384	valid_0's pr_auc: 0.714524
# [240]	valid_0's auc: 0.789983	valid_0's pr_auc: 0.714358
# [260]	valid_0's auc: 0.790466	valid_0's pr_auc: 0.714466
# [280]	valid_0's auc: 0.790448	valid_0's pr_auc: 0.714089
# [300]	valid_0's auc: 0.790811	valid_0's pr_auc: 0.71593
# [320]	valid_0's auc: 0.790997	valid_0's pr_auc: 0.718607
# [340]	valid_0's auc: 0.791408	valid_0's pr_auc: 0.718319
# [360]	valid_0's auc: 0.791356	valid_0's pr_auc: 0.719932
# [380]	valid_0's auc: 0.791557	valid_0's pr_auc: 0.719174
# [400]	valid_0's auc: 0.791687	valid_0's pr_auc: 0.718851
# [420]	valid_0's auc: 0.791598	valid_0's pr_auc: 0.717602
# [440]	valid_0's auc: 0.791648	valid_0's pr_auc: 0.717414
# Early stopping, best iteration is:
# [356]	valid_0's auc: 0.791414	valid_0's pr_auc: 0.72022
# ==========================================================
# [LightGBM] [Info] Number of positive: 4508, number of negative: 8992
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001479 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12482
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333926 -> initscore=-0.690482
# [LightGBM] [Info] Start training from score -0.690482
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.778083	valid_0's pr_auc: 0.679758
# [40]	valid_0's auc: 0.779305	valid_0's pr_auc: 0.684876
# [60]	valid_0's auc: 0.785276	valid_0's pr_auc: 0.688343
# [80]	valid_0's auc: 0.78804	valid_0's pr_auc: 0.693037
# [100]	valid_0's auc: 0.791105	valid_0's pr_auc: 0.697722
# [120]	valid_0's auc: 0.79258	valid_0's pr_auc: 0.698283
# [140]	valid_0's auc: 0.794728	valid_0's pr_auc: 0.700606
# [160]	valid_0's auc: 0.795877	valid_0's pr_auc: 0.704699
# [180]	valid_0's auc: 0.796433	valid_0's pr_auc: 0.705744
# [200]	valid_0's auc: 0.797603	valid_0's pr_auc: 0.707449
# [220]	valid_0's auc: 0.799242	valid_0's pr_auc: 0.713619
# [240]	valid_0's auc: 0.799992	valid_0's pr_auc: 0.715218
# [260]	valid_0's auc: 0.801855	valid_0's pr_auc: 0.719114
# [280]	valid_0's auc: 0.803063	valid_0's pr_auc: 0.720758
# [300]	valid_0's auc: 0.803666	valid_0's pr_auc: 0.722571
# [320]	valid_0's auc: 0.804922	valid_0's pr_auc: 0.723651
# [340]	valid_0's auc: 0.80511	valid_0's pr_auc: 0.725548
# [360]	valid_0's auc: 0.804928	valid_0's pr_auc: 0.726213
# [380]	valid_0's auc: 0.805134	valid_0's pr_auc: 0.726939
# [400]	valid_0's auc: 0.80487	valid_0's pr_auc: 0.727241
# [420]	valid_0's auc: 0.805283	valid_0's pr_auc: 0.727988
# [440]	valid_0's auc: 0.805354	valid_0's pr_auc: 0.727832
# [460]	valid_0's auc: 0.805741	valid_0's pr_auc: 0.729036
# [480]	valid_0's auc: 0.805939	valid_0's pr_auc: 0.729592
# [500]	valid_0's auc: 0.805892	valid_0's pr_auc: 0.729342
# [520]	valid_0's auc: 0.805937	valid_0's pr_auc: 0.729391
# [540]	valid_0's auc: 0.806132	valid_0's pr_auc: 0.729949
# [560]	valid_0's auc: 0.806035	valid_0's pr_auc: 0.730292
# [580]	valid_0's auc: 0.805902	valid_0's pr_auc: 0.730235
# [600]	valid_0's auc: 0.805939	valid_0's pr_auc: 0.729742
# [620]	valid_0's auc: 0.805781	valid_0's pr_auc: 0.729544
# Early stopping, best iteration is:
# [537]	valid_0's auc: 0.806179	valid_0's pr_auc: 0.730064
# ==========================================================
# [LightGBM] [Info] Number of positive: 4496, number of negative: 9004
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002530 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12573
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333037 -> initscore=-0.694481
# [LightGBM] [Info] Start training from score -0.694481
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.806174	valid_0's pr_auc: 0.713848
# [40]	valid_0's auc: 0.810383	valid_0's pr_auc: 0.717371
# [60]	valid_0's auc: 0.812134	valid_0's pr_auc: 0.716934
# [80]	valid_0's auc: 0.816332	valid_0's pr_auc: 0.723634
# [100]	valid_0's auc: 0.817714	valid_0's pr_auc: 0.725518
# [120]	valid_0's auc: 0.818404	valid_0's pr_auc: 0.729948
# [140]	valid_0's auc: 0.819085	valid_0's pr_auc: 0.731351
# [160]	valid_0's auc: 0.820195	valid_0's pr_auc: 0.73511
# [180]	valid_0's auc: 0.822209	valid_0's pr_auc: 0.73878
# [200]	valid_0's auc: 0.823461	valid_0's pr_auc: 0.738806
# [220]	valid_0's auc: 0.823823	valid_0's pr_auc: 0.73851
# [240]	valid_0's auc: 0.824504	valid_0's pr_auc: 0.738285
# [260]	valid_0's auc: 0.825305	valid_0's pr_auc: 0.739858
# [280]	valid_0's auc: 0.825845	valid_0's pr_auc: 0.740416
# [300]	valid_0's auc: 0.826315	valid_0's pr_auc: 0.742382
# [320]	valid_0's auc: 0.827104	valid_0's pr_auc: 0.742689
# [340]	valid_0's auc: 0.827475	valid_0's pr_auc: 0.743209
# [360]	valid_0's auc: 0.827337	valid_0's pr_auc: 0.744224
# [380]	valid_0's auc: 0.827755	valid_0's pr_auc: 0.74575
# [400]	valid_0's auc: 0.827925	valid_0's pr_auc: 0.746658
# [420]	valid_0's auc: 0.827955	valid_0's pr_auc: 0.747561
# [440]	valid_0's auc: 0.828391	valid_0's pr_auc: 0.749668
# [460]	valid_0's auc: 0.828349	valid_0's pr_auc: 0.749652
# [480]	valid_0's auc: 0.828214	valid_0's pr_auc: 0.749732
# [500]	valid_0's auc: 0.828803	valid_0's pr_auc: 0.750081
# [520]	valid_0's auc: 0.828877	valid_0's pr_auc: 0.751022
# [540]	valid_0's auc: 0.828975	valid_0's pr_auc: 0.750613
# [560]	valid_0's auc: 0.829182	valid_0's pr_auc: 0.750844
# [580]	valid_0's auc: 0.829226	valid_0's pr_auc: 0.751635
# [600]	valid_0's auc: 0.829248	valid_0's pr_auc: 0.752149
# [620]	valid_0's auc: 0.829481	valid_0's pr_auc: 0.752464
# [640]	valid_0's auc: 0.82964	valid_0's pr_auc: 0.752583
# [660]	valid_0's auc: 0.829975	valid_0's pr_auc: 0.753386
# [680]	valid_0's auc: 0.829975	valid_0's pr_auc: 0.753279
# [700]	valid_0's auc: 0.830007	valid_0's pr_auc: 0.75303
# [720]	valid_0's auc: 0.830269	valid_0's pr_auc: 0.75314
# [740]	valid_0's auc: 0.830264	valid_0's pr_auc: 0.753654
# [760]	valid_0's auc: 0.830425	valid_0's pr_auc: 0.75401
# [780]	valid_0's auc: 0.830309	valid_0's pr_auc: 0.753553
# [800]	valid_0's auc: 0.830329	valid_0's pr_auc: 0.754144
# [820]	valid_0's auc: 0.830465	valid_0's pr_auc: 0.754286
# [840]	valid_0's auc: 0.830455	valid_0's pr_auc: 0.754468
# [860]	valid_0's auc: 0.830503	valid_0's pr_auc: 0.754789
# [880]	valid_0's auc: 0.830256	valid_0's pr_auc: 0.754984
# [900]	valid_0's auc: 0.830489	valid_0's pr_auc: 0.755296
# [920]	valid_0's auc: 0.830439	valid_0's pr_auc: 0.755534
# [940]	valid_0's auc: 0.830399	valid_0's pr_auc: 0.755968
# [960]	valid_0's auc: 0.830546	valid_0's pr_auc: 0.756373
# [980]	valid_0's auc: 0.830692	valid_0's pr_auc: 0.75675
# [1000]	valid_0's auc: 0.830758	valid_0's pr_auc: 0.757036
# Did not meet early stopping. Best iteration is:
# [997]	valid_0's auc: 0.830777	valid_0's pr_auc: 0.756923
# ==========================================================
# [LightGBM] [Info] Number of positive: 4473, number of negative: 9027
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002399 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12564
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.331333 -> initscore=-0.702161
# [LightGBM] [Info] Start training from score -0.702161
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.795736	valid_0's pr_auc: 0.720592
# [40]	valid_0's auc: 0.79873	valid_0's pr_auc: 0.723403
# [60]	valid_0's auc: 0.799659	valid_0's pr_auc: 0.725219
# [80]	valid_0's auc: 0.800853	valid_0's pr_auc: 0.727838
# [100]	valid_0's auc: 0.802419	valid_0's pr_auc: 0.729304
# [120]	valid_0's auc: 0.80378	valid_0's pr_auc: 0.728702
# [140]	valid_0's auc: 0.804435	valid_0's pr_auc: 0.729925
# [160]	valid_0's auc: 0.805365	valid_0's pr_auc: 0.730916
# [180]	valid_0's auc: 0.805707	valid_0's pr_auc: 0.731686
# [200]	valid_0's auc: 0.805638	valid_0's pr_auc: 0.730789
# [220]	valid_0's auc: 0.806184	valid_0's pr_auc: 0.730594
# [240]	valid_0's auc: 0.806903	valid_0's pr_auc: 0.730356
# [260]	valid_0's auc: 0.807489	valid_0's pr_auc: 0.730643
# Early stopping, best iteration is:
# [176]	valid_0's auc: 0.805677	valid_0's pr_auc: 0.732222
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8148995102960628

# %%
# train_quality 데이터에 대해서 strin2num 함수 적용 int로 변환
test_quality['quality_10'] = test_quality['quality_10'].apply(string2num)

# quality 10 에 대해서 행값 평균이 200이 넘는 경우 추출
q10test_mean = test_quality.groupby('user_id').quality_10.mean()
filter1500_test = q10test_mean[q10test_mean >= 1500]
filter200_test = q10test_mean[(q10test_mean >= 200) & (q10test_mean <= 1500)]
filter50_test = q10test_mean[(q10test_mean >= 50) & (q10test_mean <= 200)]

# %%
# 인덱스 리스트 저장
q10test1500_list=[x for x in filter1500_train.index]
q10test200_list=[x for x in filter200_train.index]
q10test50_list=[x for x in filter50_train.index]

# %%
# 넘파이로 200이 넘는 경우 1 과 0 으로 표시
q10test_check = np.zeros((14999,1)) # 15000 아이디에 대해서 0 열 만들기

for idx in range(14999):
    if np.isin(idx+30000, [q10test1500_list]): # 10000부터 아이디가 시작하므로
        q10test_check[idx] = 3 #인덱스 리스트에 있으면 1 지정

for idx in range(14999):
    if np.isin(idx+30000, [q10test200_list]):
        q10test_check[idx] = 2

for idx in range(14999):
    if np.isin(idx+30000, [q10test50_list]):
        q10test_check[idx] = 1    
        
q10test_check.shape
# Out:
# (14999, 1)

# %%
# 데이터 설명을 확인하면
# test 데이터는 ueser_id가 30000부터 44998까지 총 14999개가 존재.
test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

# %%
# 시간대 나누는 함수 적용하기
test_err['timeslot'] = test_err['time'].apply(time_encoding)
test_err['day'] = test_err['time'].apply(day_encoding)
test_err['week'] = test_err['day'].apply(weekday_encoding)

# %%
# 요일별로 타임라벨링 하기 넘파이 활용
week_label_test = test_err[['user_id','week']].values
week_check_test = np.zeros((test_user_number,len(test_err['week'].unique())))

for person_idx, ch in tqdm(week_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    week_check_test[person_idx - test_user_id_min,ch - 1] += 1
week_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:49<00:00, 333054.93it/s]
# (14999, 7)

# %%
# 시간대별로 타임라벨링 하기 넘파이 활용
timeslot_label_test = test_err[['user_id','timeslot']].values
timeslot_check_test = np.zeros((test_user_number,len(test_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check_test[person_idx - test_user_id_min,ch - 1] += 1
timeslot_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:52<00:00, 314936.05it/s]
# (14999, 24)

# %%
id_error_test = test_err[['user_id','errtype']].values
error_test = np.zeros((test_user_number,42))

for person_idx, err in tqdm(id_error_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error_test[person_idx - test_user_id_min,err - 1] += 1
error_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:49<00:00, 332482.13it/s]
# (14999, 42)

# %%
# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
### 모델명에 대해서 라벨 인코딩 진행
encoder = LabelEncoder()
encoder.fit(test_err['model_nm'].astype('|S80')) ## object 변수이므로 str 변수로 변환
labels_model_test = encoder.transform(test_err['model_nm'].astype('|S80'))
test_err = pd.concat([test_err,pd.Series(labels_model_test)],axis=1)
test_err.rename(columns = {0 : 'labels_model_test'}, inplace = True)

# %%
model_label_test = test_err[['user_id','labels_model_test']].values
model_nm_test = np.zeros((test_user_number,9))

for person_idx, ch in tqdm(model_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    model_nm_test[person_idx - test_user_id_min,ch - 1] += 1
model_nm_test_ = (model_nm_test > 0).astype(int) #0보다 큰 데이터는 그냥 전부 1로 변경
model_nm_test_.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:48<00:00, 342679.79it/s]
# (14999, 9)

# %%
# 분석에 활용하도록 넘파이 데이터 결합
x1_test = np.concatenate((error_test, timeslot_check_test), axis=1) ## 에러 + 시간 
x2_test = np.concatenate((x1_test, model_nm_test_), axis=1) ## 에러 + 시간 + 모델
x3_test = np.concatenate((x2_test, week_check_test), axis=1) ## 에러 + 시간 + 모델 + 요일
x4_test = np.concatenate((x3_test, q10test_check), axis=1) ## 에러 + 시간 + 모델 + 요일 + 퀄리티 10

# %%
from pycaret.classification import *

# %%
X = pd.DataFrame(x4)
y = pd.DataFrame(problem)

# %%
X['problem'] = problem

# %%
clf = setup(data = X, target = 'problem')
# Out:
# <style  type="text/css" >
# </style><table id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row0_col1" class="data row0 col1" >5946</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row1_col1" class="data row1 col1" >problem</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row4_col1" class="data row4 col1" >(15000, 84)</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row6_col1" class="data row6 col1" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row7_col1" class="data row7 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row11_col1" class="data row11 col1" >(10499, 81)</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row12_col1" class="data row12 col1" >(4501, 81)</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_eff1ff8e_616c_11eb_9e4a_3497f6a285b1row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
#best_5 = compare_models(sort = 'Accuracy', n_select = 5)

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# IntProgress(value=0, description='Processing: ', max=79)
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         22:46:18
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style  type="text/css" >
#     #T_60ebdaa6_616f_11eb_929c_3497f6a285b1 th {
#           text-align: left;
#     }#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row2_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row3_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row4_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row5_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row6_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row7_col8,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col0,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col1,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col2,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col3,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col4,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col5,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col6,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col7,#T_60ebdaa6_616f_11eb_929c_3497f6a285b1row8_col8,#T_60ebdaa6_616f_11eb_929c ...
#             text-align:  left;
#         }</style><table id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1level0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col1" class="data row0 col1" >0.7807</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col2" class="data row0 col2" >0.8089</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col3" class="data row0 col3" >0.4766</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col4" class="data row0 col4" >0.7884</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col5" class="data row0 col5" >0.5932</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col6" class="data row0 col6" >0.4556</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col7" class="data row0 col7" >0.4831</td>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row0_col8" class="data row0 col8" >0.6490</td>
#             </tr>
#             <tr>
#                         <th id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1level0_row1" class="row_heading level0 row1" >gbc</th>
#                         <td id="T_60ebdaa6_616f_11eb_929c_3497f6a285b1row1_col0" cl
# exception calling callback for <Future at 0x1ec96fac520 state=finished raised BrokenProcessPool>
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\joblib\externals\loky\process_executor.py", line 404, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "D:\Anaconda\lib\multiprocessing\queues.py", line 116, in get
#     return _ForkingPickler.loads(res)
#   File "D:\Anaconda\lib\site-packages\xgboost\__init__.py", line 9, in <module>
#     from .core import DMatrix, DeviceQuantileDMatrix, Booster
#   File "D:\Anaconda\lib\site-packages\xgboost\core.py", line 174, in <module>
#     _LIB = _load_lib()
#   File "D:\Anaconda\lib\site-packages\xgboost\core.py", line 157, in _load_lib
#     raise XGBoostError(
# xgboost.core.XGBoostError: XGBoost Library (xgboost.dll) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['[WinError 1455] 이 작업을 완료하기 위한 페이징 파일이 너무 작습니다']
#
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\joblib\externals\loky\_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "D:\Anaconda\lib\site-packages\joblib\parallel.py", line 366, in __call__
#     self.parallel.dispatch_next()
#   File "D:\Anaconda\lib\site-packages\joblib\parallel.py", line 799, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "D:\Anaconda\lib\site-packages\joblib\parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "D:\Anaconda\lib\site-packages\joblib\parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "D:\Anaconda\lib\site-packages\joblib\_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "D:\Anaconda\lib\site-packages\joblib\externals\loky\reusable_executor.py", line 177, in submit
#     return super(_ReusablePoolExecutor, self).submit(
#   File "D:\Anaconda\lib\site-packages\joblib\externals\loky\process_executor.py", line 1102, in submit
#     raise self._flags.broken
# joblib.externals.loky.process_executor.BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
#blended_5 = blend_models(estimator_list = best_5, fold = 10, method = 'soft')

# %%
blended_3 = blend_models(estimator_list = best_3, fold = 10, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col0,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col1,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col2,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col3,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col4,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col5,#T_e03daecb_616d_11eb_9b05_3497f6a285b1row10_col6{
#             background:  yellow;
#         }</style><table id="T_e03daecb_616d_11eb_9b05_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col0" class="data row0 col0" >0.7790</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col1" class="data row0 col1" >0.8219</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col2" class="data row0 col2" >0.4576</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col3" class="data row0 col3" >0.8020</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col4" class="data row0 col4" >0.5827</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col5" class="data row0 col5" >0.4473</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row0_col6" class="data row0 col6" >0.4799</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col0" class="data row1 col0" >0.7876</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col1" class="data row1 col1" >0.8082</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col2" class="data row1 col2" >0.4504</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col3" class="data row1 col3" >0.8457</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col4" class="data row1 col4" >0.5878</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col5" class="data row1 col5" >0.4621</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row1_col6" class="data row1 col6" >0.5037</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col0" class="data row2 col0" >0.8095</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col1" class="data row2 col1" >0.8312</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col2" class="data row2 col2" >0.5637</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col3" class="data row2 col3" >0.8122</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col4" class="data row2 col4" >0.6656</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col5" class="data row2 col5" >0.5384</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row2_col6" class="data row2 col6" >0.5559</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col0" class="data row3 col0" >0.7857</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col1" class="data row3 col1" >0.8018</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col2" class="data row3 col2" >0.4873</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col3" class="data row3 col3" >0.7963</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col4" class="data row3 col4" >0.6046</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col5" class="data row3 col5" >0.4690</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row3_col6" class="data row3 col6" >0.4957</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col0" class="data row4 col0" >0.7886</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col1" class="data row4 col1" >0.8229</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col2" class="data row4 col2" >0.4958</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col3" class="data row4 col3" >0.7991</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col4" class="data row4 col4" >0.6119</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col5" class="data row4 col5" >0.4773</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row4_col6" class="data row4 col6" >0.5030</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col0" class="data row5 col0" >0.7886</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col1" class="data row5 col1" >0.8129</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col2" class="data row5 col2" >0.5014</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col3" class="data row5 col3" >0.7937</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col4" class="data row5 col4" >0.6146</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col5" class="data row5 col5" >0.4789</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row5_col6" class="data row5 col6" >0.5029</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col0" class="data row6 col0" >0.7705</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col1" class="data row6 col1" >0.8003</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col2" class="data row6 col2" >0.4504</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col3" class="data row6 col3" >0.7718</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col4" class="data row6 col4" >0.5689</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col5" class="data row6 col5" >0.4269</td>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row6_col6" class="data row6 col6" >0.4556</td>
#             </tr>
#             <tr>
#                         <th id="T_e03daecb_616d_11eb_9b05_3497f6a285b1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e03daecb_616d_11eb_9b05_3497f6a285b1row7_co

# %%
pred_holdout = predict_model(blended_3)
# Out:
# <style  type="text/css" >
# </style><table id="T_e070f67b_616d_11eb_96db_3497f6a285b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e070f67b_616d_11eb_96db_3497f6a285b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col1" class="data row0 col1" >0.7976</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col2" class="data row0 col2" >0.8169</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col3" class="data row0 col3" >0.4935</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col4" class="data row0 col4" >0.8128</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col5" class="data row0 col5" >0.6141</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col6" class="data row0 col6" >0.4878</td>
#                         <td id="T_e070f67b_616d_11eb_96db_3497f6a285b1row0_col7" class="data row0 col7" >0.5157</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(blended_3)

# %%
X_test = pd.DataFrame(x4_test)

# %%
predictions = predict_model(final_model, data = X_test)

#pycaret에서는 score이 label을 맞출 확률이기때문에 output을 제출 양식에 맞게 바꿔줍니다
x = []
for i in range(len(predictions['Score'])):
  if predictions['Label'][i] =='1.0':
    x.append(predictions['Score'][i])
  else:
    x.append(1-predictions['Score'][i])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')
sample_submssion['problem'] = x
sample_submssion.to_csv("best_3.csv", index = False)
