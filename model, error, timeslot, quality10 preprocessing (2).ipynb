# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import random
import lightgbm as lgb
import re
import seaborn as sns
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings(action='ignore')

# 필요한 함수 정의
def make_datetime(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    year  = int(x[:4])
    month = int(x[4:6])
    day   = int(x[6:8])
    hour  = int(x[8:10])
    #mim  = int(x[10:12])
    #sec  = int(x[12:])
    return dt.datetime(year, month, day, hour)

def string2num(x):
    # (,)( )과 같은 불필요한 데이터 정제
    x = re.sub(r"[^0-9]+", '', str(x))
    if x =='':
        return 0
    else:
        return int(x)


PATH = './data/'

# %%
train_err  = pd.read_csv(PATH+'train_err_data.csv')
train_quality  = pd.read_csv(PATH+'train_quality_data.csv')
train_problem  = pd.read_csv(PATH+'train_problem_data.csv')

test_err  = pd.read_csv(PATH+'test_err_data.csv')
test_quality  = pd.read_csv(PATH+'test_quality_data.csv')

# %%
# train_quality 데이터에 대해서 strin2num 함수 적용 int로 변환
train_quality['quality_10'] = train_quality['quality_10'].apply(string2num)

# %%
# quality 10 에 대해서 행값 평균이 200이 넘는 경우 추출
train_quality.groupby('user_id').quality_10.mean()[train_quality.groupby('user_id').quality_10.mean() >= 200]
# Out:
# user_id
# 10019    8299.315789
# 10032     669.235294
# 10057     259.500000
# 10062     452.000000
# 10077    5543.666667
#             ...
# 24964    7972.611111
# 24979    1001.750000
# 24981    2494.750000
# 24984    2048.500000
# 24986     332.125000
# Name: quality_10, Length: 950, dtype: float64

# %%
# 저장
filter_train=train_quality.groupby('user_id').quality_10.mean()>=200

# %%
# 인덱스 값
filter_train.index[filter_train==True]
# Out:
# Int64Index([10019, 10032, 10057, 10062, 10077, 10081, 10089, 10090, 10150,
#             10166,
#             ...
#             24892, 24900, 24920, 24922, 24934, 24964, 24979, 24981, 24984,
#             24986],
#            dtype='int64', name='user_id', length=950)

# %%
# 인덱스 리스트 저장
q10train_list=[x for x in filter_train.index[filter_train==True]]

# %%
# 넘파이로 200이 넘는 경우 1 과 0 으로 표시
q10train_check = np.zeros((15000,1)) # 15000 아이디에 대해서 0 열 만들기

for idx in range(15000):
    if np.isin(idx+10000, [q10train_list]): # 10000부터 아이디가 시작하므로
        q10train_check[idx] = 1 #인덱스 리스트에 있으면 1 지정

# %%
q10train_check.shape
# Out:
# (15000, 1)

# %%
train_user_id_max = 24999
train_user_id_min = 10000
train_user_number = 15000

# %%
##시간별 데이터 만드는 코딩
def time_encoding(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    day   = int(x[6:8])
    hour  = int(x[8:10])
    y = day*100 + hour
    for i in range(30):
        if y == (i+1)*100:
            return 0
        if y == (i+1)*100 + 1:
            return 1
        if y == (i+1)*100 + 2:
            return 2
        if y == (i+1)*100 + 3:
            return 3
        if y == (i+1)*100 + 4:
            return 4
        if y == (i+1)*100 + 5:
            return 5
        if y == (i+1)*100 + 6:
            return 6
        if y == (i+1)*100 + 7:
            return 7
        if y == (i+1)*100 + 8:
            return 8
        if y == (i+1)*100 + 9:
            return 9
        if y == (i+1)*100 + 10:
            return 10
        if y == (i+1)*100 + 11:
            return 11
        if y == (i+1)*100 + 12:
            return 12
        if y == (i+1)*100 + 13:
            return 13
        if y == (i+1)*100 + 14:
            return 14
        if y == (i+1)*100 + 15:
            return 15
        if y == (i+1)*100 + 16:
            return 16
        if y == (i+1)*100 + 17:
            return 17
        if y == (i+1)*100 + 18:
            return 18
        if y == (i+1)*100 + 19:
            return 19
        if y == (i+1)*100 + 20:
            return 20
        if y == (i+1)*100 + 21:
            return 21
        if y == (i+1)*100 + 22:
            return 22
        if y == (i+1)*100 + 23:
            return 23
        if day == 31: # 10월 31일 23:59의 경우
            return 0

# %%
#적용하기
train_err['timeslot'] = train_err['time'].apply(time_encoding)

# %%
# 시간대별로 타임라벨링 하기 넘파이 활용
timeslot_label = train_err[['user_id','timeslot']].values
timeslot_check = np.zeros((train_user_number,len(train_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check[person_idx - train_user_id_min,ch - 1] += 1
timeslot_check.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:51<00:00, 321565.09it/s]
# (15000, 24)

# %%
id_error = train_err[['user_id','errtype']].values
error = np.zeros((train_user_number,42))

for person_idx, err in tqdm(id_error):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error[person_idx - train_user_id_min,err - 1] += 1
error.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:51<00:00, 322434.01it/s]
# (15000, 42)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
### 모델명에 대해서 라벨 인코딩 진행
encoder = LabelEncoder()
encoder.fit(train_err['model_nm'].astype('|S80')) ## object 변수이므로 str 변수로 변환
labels_model = encoder.transform(train_err['model_nm'].astype('|S80'))
train_err = pd.concat([train_err,pd.Series(labels_model)],axis=1)
train_err.rename(columns = {0 : 'labels_model'}, inplace = True)

# %%
model_label = train_err[['user_id','labels_model']].values
model_nm = np.zeros((train_user_number,9))

for person_idx, ch in tqdm(model_label):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    model_nm[person_idx - train_user_id_min,ch - 1] += 1
model_nm_ = (model_nm > 0).astype(int) #0보다 큰 데이터는 그냥 전부 1로 변경
model_nm_.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16554663/16554663 [00:51<00:00, 319759.89it/s]
# (15000, 9)

# %%
# 분석에 활용하도록 넘파이 데이터 결합
x1 = np.concatenate((error, timeslot_check), axis=1) ## 펌웨어 버전 + 날짜 
x2 = np.concatenate((x1, model_nm_), axis=1) ## 펌웨어 버전 + 날짜 +시간 
x3 = np.concatenate((x2, q10train_check), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러

# %%
# Y 데이터 만들기
train_prob = pd.read_csv(PATH+'train_problem_data.csv')
problem = np.zeros(15000)
# error와 동일한 방법으로 person_idx - 10000 위치에 
# person_idx의 problem이 한 번이라도 발생했다면 1
# 없다면 0
problem[train_prob.user_id.unique()-10000] = 1 
problem.shape
# Out:
# (15000,)

# %%
# 변수 이름 변경
# x3  -> train_x
# problem-> train_y

train_x = x3
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 76)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'task' : 'train',
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'learning_rate' : 0.01,
                'max_bin' : 255,
                'feature_fraction' : 0.8,
                'min_data_in_leaf'     : 10,
                'num_threads'    : 4, 
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 10 Kfold cross validation
k_fold = KFold(n_splits=10, shuffle=True, random_state=150)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 100
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 4543, number of negative: 8957
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001838 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10787
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.336519 -> initscore=-0.678848
# [LightGBM] [Info] Start training from score -0.678848
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.79948	valid_0's pr_auc: 0.7137
# [40]	valid_0's auc: 0.803802	valid_0's pr_auc: 0.715163
# [60]	valid_0's auc: 0.805251	valid_0's pr_auc: 0.715144
# [80]	valid_0's auc: 0.805641	valid_0's pr_auc: 0.717073
# [100]	valid_0's auc: 0.806369	valid_0's pr_auc: 0.716956
# [120]	valid_0's auc: 0.806915	valid_0's pr_auc: 0.716932
# Early stopping, best iteration is:
# [33]	valid_0's auc: 0.804153	valid_0's pr_auc: 0.718643
# ==========================================================
# [LightGBM] [Info] Number of positive: 4521, number of negative: 8979
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10790
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334889 -> initscore=-0.686155
# [LightGBM] [Info] Start training from score -0.686155
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.799534	valid_0's pr_auc: 0.680748
# [40]	valid_0's auc: 0.80095	valid_0's pr_auc: 0.697374
# [60]	valid_0's auc: 0.801746	valid_0's pr_auc: 0.697486
# [80]	valid_0's auc: 0.803007	valid_0's pr_auc: 0.704064
# [100]	valid_0's auc: 0.805586	valid_0's pr_auc: 0.71615
# [120]	valid_0's auc: 0.807732	valid_0's pr_auc: 0.718002
# [140]	valid_0's auc: 0.809114	valid_0's pr_auc: 0.719595
# [160]	valid_0's auc: 0.810445	valid_0's pr_auc: 0.720429
# [180]	valid_0's auc: 0.810809	valid_0's pr_auc: 0.720527
# [200]	valid_0's auc: 0.811884	valid_0's pr_auc: 0.72192
# [220]	valid_0's auc: 0.812818	valid_0's pr_auc: 0.72231
# [240]	valid_0's auc: 0.813152	valid_0's pr_auc: 0.723269
# [260]	valid_0's auc: 0.813485	valid_0's pr_auc: 0.722223
# [280]	valid_0's auc: 0.813274	valid_0's pr_auc: 0.72166
# [300]	valid_0's auc: 0.813804	valid_0's pr_auc: 0.721972
# [320]	valid_0's auc: 0.813466	valid_0's pr_auc: 0.72093
# [340]	valid_0's auc: 0.813706	valid_0's pr_auc: 0.71885
# Early stopping, best iteration is:
# [242]	valid_0's auc: 0.813236	valid_0's pr_auc: 0.723368
# ==========================================================
# [LightGBM] [Info] Number of positive: 4502, number of negative: 8998
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10787
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333481 -> initscore=-0.692481
# [LightGBM] [Info] Start training from score -0.692481
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.793977	valid_0's pr_auc: 0.662361
# [40]	valid_0's auc: 0.793882	valid_0's pr_auc: 0.688599
# [60]	valid_0's auc: 0.797241	valid_0's pr_auc: 0.697875
# [80]	valid_0's auc: 0.79954	valid_0's pr_auc: 0.69817
# [100]	valid_0's auc: 0.800815	valid_0's pr_auc: 0.699001
# [120]	valid_0's auc: 0.802204	valid_0's pr_auc: 0.702144
# [140]	valid_0's auc: 0.802616	valid_0's pr_auc: 0.703907
# [160]	valid_0's auc: 0.802536	valid_0's pr_auc: 0.704292
# [180]	valid_0's auc: 0.803414	valid_0's pr_auc: 0.70562
# [200]	valid_0's auc: 0.804873	valid_0's pr_auc: 0.706726
# [220]	valid_0's auc: 0.805697	valid_0's pr_auc: 0.708409
# [240]	valid_0's auc: 0.807402	valid_0's pr_auc: 0.710299
# [260]	valid_0's auc: 0.807478	valid_0's pr_auc: 0.709977
# [280]	valid_0's auc: 0.807729	valid_0's pr_auc: 0.71055
# [300]	valid_0's auc: 0.807738	valid_0's pr_auc: 0.709934
# [320]	valid_0's auc: 0.808331	valid_0's pr_auc: 0.710338
# [340]	valid_0's auc: 0.808215	valid_0's pr_auc: 0.70657
# [360]	valid_0's auc: 0.808723	valid_0's pr_auc: 0.706479
# [380]	valid_0's auc: 0.808795	valid_0's pr_auc: 0.707509
# [400]	valid_0's auc: 0.808961	valid_0's pr_auc: 0.708413
# Early stopping, best iteration is:
# [311]	valid_0's auc: 0.808185	valid_0's pr_auc: 0.710819
# ==========================================================
# [LightGBM] [Info] Number of positive: 4507, number of negative: 8993
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006607 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10793
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333852 -> initscore=-0.690815
# [LightGBM] [Info] Start training from score -0.690815
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.816272	valid_0's pr_auc: 0.728597
# [40]	valid_0's auc: 0.815535	valid_0's pr_auc: 0.710613
# [60]	valid_0's auc: 0.818719	valid_0's pr_auc: 0.72147
# [80]	valid_0's auc: 0.821164	valid_0's pr_auc: 0.725926
# [100]	valid_0's auc: 0.823073	valid_0's pr_auc: 0.728094
# [120]	valid_0's auc: 0.824374	valid_0's pr_auc: 0.732715
# [140]	valid_0's auc: 0.825815	valid_0's pr_auc: 0.735063
# [160]	valid_0's auc: 0.827279	valid_0's pr_auc: 0.738098
# [180]	valid_0's auc: 0.828072	valid_0's pr_auc: 0.740497
# [200]	valid_0's auc: 0.828626	valid_0's pr_auc: 0.743117
# [220]	valid_0's auc: 0.829256	valid_0's pr_auc: 0.743474
# [240]	valid_0's auc: 0.830064	valid_0's pr_auc: 0.745093
# [260]	valid_0's auc: 0.830477	valid_0's pr_auc: 0.7457
# [280]	valid_0's auc: 0.830976	valid_0's pr_auc: 0.746081
# [300]	valid_0's auc: 0.831019	valid_0's pr_auc: 0.746618
# [320]	valid_0's auc: 0.831293	valid_0's pr_auc: 0.747135
# [340]	valid_0's auc: 0.831536	valid_0's pr_auc: 0.746559
# [360]	valid_0's auc: 0.831927	valid_0's pr_auc: 0.748118
# [380]	valid_0's auc: 0.831804	valid_0's pr_auc: 0.748437
# [400]	valid_0's auc: 0.831987	valid_0's pr_auc: 0.748806
# [420]	valid_0's auc: 0.832092	valid_0's pr_auc: 0.74933
# [440]	valid_0's auc: 0.832149	valid_0's pr_auc: 0.749472
# [460]	valid_0's auc: 0.831895	valid_0's pr_auc: 0.749481
# [480]	valid_0's auc: 0.831575	valid_0's pr_auc: 0.748564
# [500]	valid_0's auc: 0.831508	valid_0's pr_auc: 0.748038
# [520]	valid_0's auc: 0.83179	valid_0's pr_auc: 0.748361
# [540]	valid_0's auc: 0.831802	valid_0's pr_auc: 0.748057
# Early stopping, best iteration is:
# [442]	valid_0's auc: 0.832195	valid_0's pr_auc: 0.749573
# ==========================================================
# [LightGBM] [Info] Number of positive: 4495, number of negative: 9005
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10785
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332963 -> initscore=-0.694814
# [LightGBM] [Info] Start training from score -0.694814
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.819846	valid_0's pr_auc: 0.749202
# [40]	valid_0's auc: 0.820526	valid_0's pr_auc: 0.746458
# [60]	valid_0's auc: 0.820584	valid_0's pr_auc: 0.745699
# [80]	valid_0's auc: 0.821352	valid_0's pr_auc: 0.749569
# [100]	valid_0's auc: 0.822228	valid_0's pr_auc: 0.751489
# [120]	valid_0's auc: 0.821912	valid_0's pr_auc: 0.753181
# [140]	valid_0's auc: 0.822507	valid_0's pr_auc: 0.754096
# [160]	valid_0's auc: 0.823354	valid_0's pr_auc: 0.755151
# [180]	valid_0's auc: 0.824533	valid_0's pr_auc: 0.75602
# [200]	valid_0's auc: 0.825665	valid_0's pr_auc: 0.756899
# [220]	valid_0's auc: 0.826385	valid_0's pr_auc: 0.756931
# [240]	valid_0's auc: 0.827315	valid_0's pr_auc: 0.757575
# [260]	valid_0's auc: 0.828081	valid_0's pr_auc: 0.757227
# [280]	valid_0's auc: 0.828672	valid_0's pr_auc: 0.757558
# [300]	valid_0's auc: 0.829482	valid_0's pr_auc: 0.759326
# [320]	valid_0's auc: 0.82996	valid_0's pr_auc: 0.761508
# [340]	valid_0's auc: 0.830543	valid_0's pr_auc: 0.760839
# [360]	valid_0's auc: 0.830987	valid_0's pr_auc: 0.761635
# [380]	valid_0's auc: 0.831212	valid_0's pr_auc: 0.760733
# [400]	valid_0's auc: 0.831462	valid_0's pr_auc: 0.761281
# [420]	valid_0's auc: 0.831643	valid_0's pr_auc: 0.760414
# [440]	valid_0's auc: 0.831936	valid_0's pr_auc: 0.759749
# Early stopping, best iteration is:
# [351]	valid_0's auc: 0.830786	valid_0's pr_auc: 0.762233
# ==========================================================
# [LightGBM] [Info] Number of positive: 4489, number of negative: 9011
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10777
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.332519 -> initscore=-0.696816
# [LightGBM] [Info] Start training from score -0.696816
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.800526	valid_0's pr_auc: 0.733923
# [40]	valid_0's auc: 0.800862	valid_0's pr_auc: 0.72593
# [60]	valid_0's auc: 0.802648	valid_0's pr_auc: 0.728521
# [80]	valid_0's auc: 0.803551	valid_0's pr_auc: 0.733623
# [100]	valid_0's auc: 0.804191	valid_0's pr_auc: 0.736387
# [120]	valid_0's auc: 0.80553	valid_0's pr_auc: 0.737121
# [140]	valid_0's auc: 0.806717	valid_0's pr_auc: 0.738902
# [160]	valid_0's auc: 0.807968	valid_0's pr_auc: 0.741449
# [180]	valid_0's auc: 0.808926	valid_0's pr_auc: 0.743184
# [200]	valid_0's auc: 0.809626	valid_0's pr_auc: 0.743857
# [220]	valid_0's auc: 0.810186	valid_0's pr_auc: 0.745511
# [240]	valid_0's auc: 0.811308	valid_0's pr_auc: 0.746678
# [260]	valid_0's auc: 0.812523	valid_0's pr_auc: 0.747763
# [280]	valid_0's auc: 0.813427	valid_0's pr_auc: 0.748523
# [300]	valid_0's auc: 0.813536	valid_0's pr_auc: 0.747705
# [320]	valid_0's auc: 0.813758	valid_0's pr_auc: 0.748399
# [340]	valid_0's auc: 0.81391	valid_0's pr_auc: 0.74865
# [360]	valid_0's auc: 0.814217	valid_0's pr_auc: 0.749572
# [380]	valid_0's auc: 0.814327	valid_0's pr_auc: 0.75021
# [400]	valid_0's auc: 0.814969	valid_0's pr_auc: 0.750354
# [420]	valid_0's auc: 0.815208	valid_0's pr_auc: 0.751018
# [440]	valid_0's auc: 0.81562	valid_0's pr_auc: 0.751181
# [460]	valid_0's auc: 0.815503	valid_0's pr_auc: 0.749718
# [480]	valid_0's auc: 0.815641	valid_0's pr_auc: 0.750136
# [500]	valid_0's auc: 0.815891	valid_0's pr_auc: 0.74983
# [520]	valid_0's auc: 0.815891	valid_0's pr_auc: 0.74947
# [540]	valid_0's auc: 0.815726	valid_0's pr_auc: 0.750099
# Early stopping, best iteration is:
# [444]	valid_0's auc: 0.815594	valid_0's pr_auc: 0.751547
# ==========================================================
# [LightGBM] [Info] Number of positive: 4466, number of negative: 9034
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10755
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.330815 -> initscore=-0.704502
# [LightGBM] [Info] Start training from score -0.704502
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.779415	valid_0's pr_auc: 0.707305
# [40]	valid_0's auc: 0.779057	valid_0's pr_auc: 0.695221
# [60]	valid_0's auc: 0.78316	valid_0's pr_auc: 0.698941
# [80]	valid_0's auc: 0.783682	valid_0's pr_auc: 0.69573
# [100]	valid_0's auc: 0.785015	valid_0's pr_auc: 0.708035
# [120]	valid_0's auc: 0.785715	valid_0's pr_auc: 0.712845
# [140]	valid_0's auc: 0.786265	valid_0's pr_auc: 0.714692
# [160]	valid_0's auc: 0.786935	valid_0's pr_auc: 0.715814
# [180]	valid_0's auc: 0.787877	valid_0's pr_auc: 0.716522
# [200]	valid_0's auc: 0.78879	valid_0's pr_auc: 0.71755
# [220]	valid_0's auc: 0.789042	valid_0's pr_auc: 0.717932
# [240]	valid_0's auc: 0.789611	valid_0's pr_auc: 0.718286
# [260]	valid_0's auc: 0.789999	valid_0's pr_auc: 0.719091
# [280]	valid_0's auc: 0.790237	valid_0's pr_auc: 0.720078
# [300]	valid_0's auc: 0.790394	valid_0's pr_auc: 0.720418
# [320]	valid_0's auc: 0.790677	valid_0's pr_auc: 0.721118
# [340]	valid_0's auc: 0.79101	valid_0's pr_auc: 0.719802
# [360]	valid_0's auc: 0.791117	valid_0's pr_auc: 0.720572
# [380]	valid_0's auc: 0.791034	valid_0's pr_auc: 0.720483
# [400]	valid_0's auc: 0.790762	valid_0's pr_auc: 0.719237
# [420]	valid_0's auc: 0.790344	valid_0's pr_auc: 0.718198
# Early stopping, best iteration is:
# [321]	valid_0's auc: 0.790702	valid_0's pr_auc: 0.72126
# ==========================================================
# [LightGBM] [Info] Number of positive: 4508, number of negative: 8992
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10695
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333926 -> initscore=-0.690482
# [LightGBM] [Info] Start training from score -0.690482
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.779546	valid_0's pr_auc: 0.699629
# [40]	valid_0's auc: 0.780848	valid_0's pr_auc: 0.697769
# [60]	valid_0's auc: 0.784345	valid_0's pr_auc: 0.700488
# [80]	valid_0's auc: 0.787762	valid_0's pr_auc: 0.701501
# [100]	valid_0's auc: 0.789803	valid_0's pr_auc: 0.703505
# [120]	valid_0's auc: 0.791019	valid_0's pr_auc: 0.70583
# [140]	valid_0's auc: 0.792306	valid_0's pr_auc: 0.708291
# [160]	valid_0's auc: 0.793594	valid_0's pr_auc: 0.709245
# [180]	valid_0's auc: 0.794065	valid_0's pr_auc: 0.712274
# [200]	valid_0's auc: 0.795185	valid_0's pr_auc: 0.715091
# [220]	valid_0's auc: 0.796748	valid_0's pr_auc: 0.717911
# [240]	valid_0's auc: 0.798689	valid_0's pr_auc: 0.720162
# [260]	valid_0's auc: 0.800045	valid_0's pr_auc: 0.722283
# [280]	valid_0's auc: 0.801263	valid_0's pr_auc: 0.724347
# [300]	valid_0's auc: 0.801952	valid_0's pr_auc: 0.725331
# [320]	valid_0's auc: 0.802999	valid_0's pr_auc: 0.727352
# [340]	valid_0's auc: 0.803271	valid_0's pr_auc: 0.728621
# [360]	valid_0's auc: 0.803608	valid_0's pr_auc: 0.729572
# [380]	valid_0's auc: 0.803848	valid_0's pr_auc: 0.730781
# [400]	valid_0's auc: 0.803531	valid_0's pr_auc: 0.730213
# [420]	valid_0's auc: 0.80341	valid_0's pr_auc: 0.729886
# [440]	valid_0's auc: 0.803273	valid_0's pr_auc: 0.730208
# [460]	valid_0's auc: 0.803279	valid_0's pr_auc: 0.73083
# Early stopping, best iteration is:
# [370]	valid_0's auc: 0.803959	valid_0's pr_auc: 0.730382
# ==========================================================
# [LightGBM] [Info] Number of positive: 4496, number of negative: 9004
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004245 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10786
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333037 -> initscore=-0.694481
# [LightGBM] [Info] Start training from score -0.694481
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.813204	valid_0's pr_auc: 0.733908
# [40]	valid_0's auc: 0.814718	valid_0's pr_auc: 0.724952
# [60]	valid_0's auc: 0.817181	valid_0's pr_auc: 0.726618
# [80]	valid_0's auc: 0.819241	valid_0's pr_auc: 0.733614
# [100]	valid_0's auc: 0.820113	valid_0's pr_auc: 0.735721
# [120]	valid_0's auc: 0.821487	valid_0's pr_auc: 0.737146
# [140]	valid_0's auc: 0.82221	valid_0's pr_auc: 0.737618
# [160]	valid_0's auc: 0.822925	valid_0's pr_auc: 0.738984
# [180]	valid_0's auc: 0.823955	valid_0's pr_auc: 0.741637
# [200]	valid_0's auc: 0.825108	valid_0's pr_auc: 0.74296
# [220]	valid_0's auc: 0.825791	valid_0's pr_auc: 0.742351
# [240]	valid_0's auc: 0.826156	valid_0's pr_auc: 0.742248
# [260]	valid_0's auc: 0.826435	valid_0's pr_auc: 0.742182
# [280]	valid_0's auc: 0.827048	valid_0's pr_auc: 0.741627
# [300]	valid_0's auc: 0.827562	valid_0's pr_auc: 0.742575
# [320]	valid_0's auc: 0.82825	valid_0's pr_auc: 0.742801
# Early stopping, best iteration is:
# [232]	valid_0's auc: 0.826293	valid_0's pr_auc: 0.743403
# ==========================================================
# [LightGBM] [Info] Number of positive: 4473, number of negative: 9027
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004108 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10777
# [LightGBM] [Info] Number of data points in the train set: 13500, number of used features: 75
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.331333 -> initscore=-0.702161
# [LightGBM] [Info] Start training from score -0.702161
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's auc: 0.797949	valid_0's pr_auc: 0.725167
# [40]	valid_0's auc: 0.801174	valid_0's pr_auc: 0.721505
# [60]	valid_0's auc: 0.803566	valid_0's pr_auc: 0.725132
# [80]	valid_0's auc: 0.803979	valid_0's pr_auc: 0.728983
# [100]	valid_0's auc: 0.80486	valid_0's pr_auc: 0.728847
# [120]	valid_0's auc: 0.805999	valid_0's pr_auc: 0.730722
# [140]	valid_0's auc: 0.806393	valid_0's pr_auc: 0.731657
# [160]	valid_0's auc: 0.806815	valid_0's pr_auc: 0.732667
# [180]	valid_0's auc: 0.807213	valid_0's pr_auc: 0.732272
# [200]	valid_0's auc: 0.807498	valid_0's pr_auc: 0.731796
# [220]	valid_0's auc: 0.80785	valid_0's pr_auc: 0.732271
# [240]	valid_0's auc: 0.808498	valid_0's pr_auc: 0.731355
# Early stopping, best iteration is:
# [159]	valid_0's auc: 0.80687	valid_0's pr_auc: 0.73343
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8131972795667093

# %%
# 정리
# q10train_check - 퀄리티10 데이터가 평균이 200이 넘는 경우, 데이터프레임
# timeslot_check - 시간대별 데이터
# error - 에러타입별 데이터
# model_nm_ - 모델별 데이터

# %%
# train_quality 데이터에 대해서 strin2num 함수 적용 int로 변환
test_quality['quality_10'] = test_quality['quality_10'].apply(string2num)

# quality 10 에 대해서 행값 평균이 200이 넘는 경우 추출
test_quality.groupby('user_id').quality_10.mean()[test_quality.groupby('user_id').quality_10.mean() >= 200]
# Out:
# user_id
# 30001     854.333333
# 30005    1580.937500
# 30008     458.571429
# 30009    3086.333333
# 30061     718.500000
#             ...
# 44949     978.100000
# 44956    4532.000000
# 44971     425.513514
# 44978    2221.000000
# 44985     355.000000
# Name: quality_10, Length: 934, dtype: float64

# %%
# 저장
filter_test=test_quality.groupby('user_id').quality_10.mean()>=200
# 인덱스 값
filter_test.index[filter_test==True]
# 인덱스 리스트 저장
q10test_list=[x for x in filter_test.index[filter_test==True]]

# %%
# 넘파이로 200이 넘는 경우 1 과 0 으로 표시
q10test_check = np.zeros((14999,1)) # 15000 아이디에 대해서 0 열 만들기

for idx in range(14999):
    if np.isin(idx+30000, [q10test_list]): # 10000부터 아이디가 시작하므로
        q10test_check[idx] = 1 #인덱스 리스트에 있으면 1 지정

# %%
q10test_check.shape
# Out:
# (14999, 1)

# %%
# 데이터 설명을 확인하면
# test 데이터는 ueser_id가 30000부터 44998까지 총 14999개가 존재.
test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

# %%
# 시간대 나누는 함수 적용하기
test_err['timeslot'] = test_err['time'].apply(time_encoding)

# %%
# 시간대별로 타임라벨링 하기 넘파이 활용
timeslot_label_test = test_err[['user_id','timeslot']].values
timeslot_check_test = np.zeros((test_user_number,len(test_err['timeslot'].unique())))

for person_idx, ch in tqdm(timeslot_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    timeslot_check_test[person_idx - test_user_id_min,ch - 1] += 1
timeslot_check_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:51<00:00, 320185.85it/s]
# (14999, 24)

# %%
id_error_test = test_err[['user_id','errtype']].values
error_test = np.zeros((test_user_number,42))

for person_idx, err in tqdm(id_error_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error_test[person_idx - test_user_id_min,err - 1] += 1
error_test.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:52<00:00, 317883.31it/s]
# (14999, 42)

# %%
# 숫자 값으로 변환하기 위해 LabelEncoder로 먼저 변환한다.
### 모델명에 대해서 라벨 인코딩 진행
encoder = LabelEncoder()
encoder.fit(test_err['model_nm'].astype('|S80')) ## object 변수이므로 str 변수로 변환
labels_model_test = encoder.transform(test_err['model_nm'].astype('|S80'))
test_err = pd.concat([test_err,pd.Series(labels_model_test)],axis=1)
test_err.rename(columns = {0 : 'labels_model_test'}, inplace = True)

# %%
model_label_test = test_err[['user_id','labels_model_test']].values
model_nm_test = np.zeros((test_user_number,9))

for person_idx, ch in tqdm(model_label_test):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    model_nm_test[person_idx - test_user_id_min,ch - 1] += 1
model_nm_test_ = (model_nm_test > 0).astype(int) #0보다 큰 데이터는 그냥 전부 1로 변경
model_nm_test_.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 16532648/16532648 [00:51<00:00, 322910.64it/s]
# (14999, 9)

# %%
model_nm_test_ = (model_nm_test > 0).astype(int) #0보다 큰 데이터는 그냥 전부 1로 변경
model_nm_test_.shape
# Out:
# (14999, 9)

# %%
# 분석에 활용하도록 넘파이 데이터 결합
x1_test = np.concatenate((error_test, timeslot_check_test), axis=1) ## 펌웨어 버전 + 날짜 
x2_test = np.concatenate((x1_test, model_nm_test_), axis=1) ## 펌웨어 버전 + 날짜 +시간 
x3_test = np.concatenate((x2_test, q10test_check), axis=1) ## 펌웨어 버전 + 날짜 +시간 + 에러

# %%
x3_test.shape
# Out:
# (14999, 76)

# %%
from pycaret.classification import *

# %%
X = pd.DataFrame(x3)
y = pd.DataFrame(problem)

# %%
X['problem'] = problem

# %%
clf = setup(data = X, target = 'problem')
# Out:
# <style  type="text/css" >
# </style><table id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row0_col1" class="data row0 col1" >5542</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row1_col1" class="data row1 col1" >problem</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row4_col1" class="data row4 col1" >(15000, 77)</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row6_col1" class="data row6 col1" >66</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row7_col1" class="data row7 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row11_col1" class="data row11 col1" >(10499, 75)</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row12_col1" class="data row12 col1" >(4501, 75)</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_3eb562bc_5ff3_11eb_a58b_30c9ab536b38row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
#Stacking model 만들기
lightgbm_ = create_model('lightgbm') 
catboost_ = create_model('catboost') 
xgboost_ = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col0,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col1,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col2,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col3,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col4,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col5,#T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row10_col6{
#             background:  yellow;
#         }</style><table id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col0" class="data row0 col0" >0.7600</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col1" class="data row0 col1" >0.7730</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col2" class="data row0 col2" >0.5157</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col3" class="data row0 col3" >0.6882</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col4" class="data row0 col4" >0.5896</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col5" class="data row0 col5" >0.4249</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row0_col6" class="data row0 col6" >0.4337</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col0" class="data row1 col0" >0.7838</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col1" class="data row1 col1" >0.8008</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col2" class="data row1 col2" >0.5470</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col3" class="data row1 col3" >0.7385</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col4" class="data row1 col4" >0.6285</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col5" class="data row1 col5" >0.4808</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row1_col6" class="data row1 col6" >0.4915</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col0" class="data row2 col0" >0.7800</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col1" class="data row2 col1" >0.8053</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col2" class="data row2 col2" >0.5299</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col3" class="data row2 col3" >0.7381</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col4" class="data row2 col4" >0.6169</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col5" class="data row2 col5" >0.4684</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row2_col6" class="data row2 col6" >0.4810</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col0" class="data row3 col0" >0.7571</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col1" class="data row3 col1" >0.7809</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col2" class="data row3 col2" >0.5128</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col3" class="data row3 col3" >0.6818</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col4" class="data row3 col4" >0.5854</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col5" class="data row3 col5" >0.4185</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row3_col6" class="data row3 col6" >0.4270</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col0" class="data row4 col0" >0.7752</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col1" class="data row4 col1" >0.8045</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col2" class="data row4 col2" >0.5356</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col3" class="data row4 col3" >0.7203</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col4" class="data row4 col4" >0.6144</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col5" class="data row4 col5" >0.4606</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row4_col6" class="data row4 col6" >0.4706</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col0" class="data row5 col0" >0.7848</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col1" class="data row5 col1" >0.7935</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col2" class="data row5 col2" >0.5499</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col3" class="data row5 col3" >0.7395</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col4" class="data row5 col4" >0.6307</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col5" class="data row5 col5" >0.4834</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row5_col6" class="data row5 col6" >0.4940</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col0" class="data row6 col0" >0.7657</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col1" class="data row6 col1" >0.7850</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col2" class="data row6 col2" >0.5114</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col3" class="data row6 col3" >0.7087</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col4" class="data row6 col4" >0.5941</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col5" class="data row6 col5" >0.4354</td>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row6_col6" class="data row6 col6" >0.4468</td>
#             </tr>
#             <tr>
#                         <th id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_26b28cc7_5ff5_11eb_8735_30c9ab536b38row7_co
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a63d7ab56b14> in <module>
#       3 catboost_ = create_model('catboost')
#       4 xgboost_ = create_model('xgboost')
# ----> 5 stacker = stack_model(estimator_list = [lightgbm_, xgboost_], meta_model = catboost_)
#
# NameError: name 'stack_model' is not defined

# %%
stacker_2 = stack_models(estimator_list = [lightgbm_, xgboost_], meta_model = catboost_)
# Out:
# <style  type="text/css" >
# #T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col0,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col1,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col2,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col3,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col4,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col5,#T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row10_col6{
#             background:  yellow;
#         }</style><table id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col0" class="data row0 col0" >0.7733</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col1" class="data row0 col1" >0.7905</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col2" class="data row0 col2" >0.4815</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col3" class="data row0 col3" >0.7511</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col4" class="data row0 col4" >0.5868</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col5" class="data row0 col5" >0.4408</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row0_col6" class="data row0 col6" >0.4614</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col0" class="data row1 col0" >0.7981</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col1" class="data row1 col1" >0.8288</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col2" class="data row1 col2" >0.5214</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col3" class="data row1 col3" >0.8062</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col4" class="data row1 col4" >0.6332</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col5" class="data row1 col5" >0.5026</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row1_col6" class="data row1 col6" >0.5253</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col0" class="data row2 col0" >0.7800</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col1" class="data row2 col1" >0.8183</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col2" class="data row2 col2" >0.5128</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col3" class="data row2 col3" >0.7500</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col4" class="data row2 col4" >0.6091</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col5" class="data row2 col5" >0.4635</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row2_col6" class="data row2 col6" >0.4797</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col0" class="data row3 col0" >0.7857</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col1" class="data row3 col1" >0.8176</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col2" class="data row3 col2" >0.5185</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col3" class="data row3 col3" >0.7647</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col4" class="data row3 col4" >0.6180</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col5" class="data row3 col5" >0.4766</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row3_col6" class="data row3 col6" >0.4940</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col0" class="data row4 col0" >0.7914</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col1" class="data row4 col1" >0.8158</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col2" class="data row4 col2" >0.5071</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col3" class="data row4 col3" >0.7946</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col4" class="data row4 col4" >0.6191</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col5" class="data row4 col5" >0.4850</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row4_col6" class="data row4 col6" >0.5082</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col0" class="data row5 col0" >0.7971</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col1" class="data row5 col1" >0.8119</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col2" class="data row5 col2" >0.4957</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col3" class="data row5 col3" >0.8286</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col4" class="data row5 col4" >0.6203</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col5" class="data row5 col5" >0.4936</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row5_col6" class="data row5 col6" >0.5239</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col0" class="data row6 col0" >0.7914</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col1" class="data row6 col1" >0.8086</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col2" class="data row6 col2" >0.5170</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col3" class="data row6 col3" >0.7879</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col4" class="data row6 col4" >0.6244</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col5" class="data row6 col5" >0.4885</td>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row6_col6" class="data row6 col6" >0.5092</td>
#             </tr>
#             <tr>
#                         <th id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d04b6a27_5ff5_11eb_8e9c_30c9ab536b38row7_co

# %%
stack_pred_holdout = predict_model(stacker_2)
# Out:
# <style  type="text/css" >
# </style><table id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col0" class="data row0 col0" >Stacking Classifier</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col1" class="data row0 col1" >0.7858</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col2" class="data row0 col2" >0.8099</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col3" class="data row0 col3" >0.4929</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col4" class="data row0 col4" >0.7773</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col5" class="data row0 col5" >0.6033</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col6" class="data row0 col6" >0.4665</td>
#                         <td id="T_d08303f4_5ff5_11eb_bfd3_30c9ab536b38row0_col7" class="data row0 col7" >0.4892</td>
#             </tr>
#     </tbody></table>

# %%
stacker_1 = stack_models(estimator_list = [catboost_], meta_model = lightgbm_)
# Out:
# <style  type="text/css" >
# #T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col0,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col1,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col2,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col3,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col4,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col5,#T_08107bf0_5ffa_11eb_b393_30c9ab536b38row10_col6{
#             background:  yellow;
#         }</style><table id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col0" class="data row0 col0" >0.7800</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col1" class="data row0 col1" >0.8032</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col2" class="data row0 col2" >0.4929</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col3" class="data row0 col3" >0.7655</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col4" class="data row0 col4" >0.5997</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col5" class="data row0 col5" >0.4576</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row0_col6" class="data row0 col6" >0.4787</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col0" class="data row1 col0" >0.7933</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col1" class="data row1 col1" >0.8122</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col2" class="data row1 col2" >0.5442</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col3" class="data row1 col3" >0.7702</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col4" class="data row1 col4" >0.6377</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col5" class="data row1 col5" >0.4991</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row1_col6" class="data row1 col6" >0.5138</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col0" class="data row2 col0" >0.7924</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col1" class="data row2 col1" >0.8159</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col2" class="data row2 col2" >0.5328</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col3" class="data row2 col3" >0.7759</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col4" class="data row2 col4" >0.6318</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col5" class="data row2 col5" >0.4941</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row2_col6" class="data row2 col6" >0.5110</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col0" class="data row3 col0" >0.7810</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col1" class="data row3 col1" >0.8137</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col2" class="data row3 col2" >0.5128</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col3" class="data row3 col3" >0.7531</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col4" class="data row3 col4" >0.6102</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col5" class="data row3 col5" >0.4654</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row3_col6" class="data row3 col6" >0.4820</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col0" class="data row4 col0" >0.7857</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col1" class="data row4 col1" >0.8134</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col2" class="data row4 col2" >0.4986</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col3" class="data row4 col3" >0.7812</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col4" class="data row4 col4" >0.6087</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col5" class="data row4 col5" >0.4709</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row4_col6" class="data row4 col6" >0.4934</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col0" class="data row5 col0" >0.8048</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col1" class="data row5 col1" >0.8164</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col2" class="data row5 col2" >0.5242</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col3" class="data row5 col3" >0.8288</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col4" class="data row5 col4" >0.6422</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col5" class="data row5 col5" >0.5172</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row5_col6" class="data row5 col6" >0.5428</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col0" class="data row6 col0" >0.7848</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col1" class="data row6 col1" >0.8006</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col2" class="data row6 col2" >0.5085</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col3" class="data row6 col3" >0.7716</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col4" class="data row6 col4" >0.6130</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col5" class="data row6 col5" >0.4725</td>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row6_col6" class="data row6 col6" >0.4922</td>
#             </tr>
#             <tr>
#                         <th id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_08107bf0_5ffa_11eb_b393_30c9ab536b38row7_co

# %%
stack_pred_holdout_1 = predict_model(stacker_1)
# Out:
# <style  type="text/css" >
# </style><table id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col0" class="data row0 col0" >Stacking Classifier</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col1" class="data row0 col1" >0.7856</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col2" class="data row0 col2" >0.8021</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col3" class="data row0 col3" >0.4943</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col4" class="data row0 col4" >0.7753</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col5" class="data row0 col5" >0.6037</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col6" class="data row0 col6" >0.4664</td>
#                         <td id="T_083c9792_5ffa_11eb_b6eb_30c9ab536b38row0_col7" class="data row0 col7" >0.4886</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(stacker_1)

# %%
#best_5 = compare_models(sort = 'Accuracy', n_select = 5)

# %%
best_2 = compare_models(sort = 'Accuracy', n_select = 2)
# Out:
# <style  type="text/css" >
#     #T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38 th {
#           text-align: left;
#     }#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col0,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col3,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col6,#T_9f1afa1f_5ff3_11 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col1,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col2,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col5,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col6,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col7,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col4,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row12_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row0_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row1_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row2_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row3_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row4_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row5_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row6_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row7_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row8_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row9_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row10_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row12_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row13_col8,#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f1afa1f_5ff3_11eb_8261_30c9ab536b38level0_row0" class="row_heading level0 row0" >catboost</t

# %%
#blended_5 = blend_models(estimator_list = best_5, fold = 10, method = 'soft')

# %%
blended_2 = blend_models(estimator_list = best_2, fold = 10, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col0,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col1,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col2,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col3,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col4,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col5,#T_dac0a009_5ff3_11eb_9393_30c9ab536b38row10_col6{
#             background:  yellow;
#         }</style><table id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col0" class="data row0 col0" >0.7743</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col1" class="data row0 col1" >0.7958</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col2" class="data row0 col2" >0.4644</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col3" class="data row0 col3" >0.7689</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col4" class="data row0 col4" >0.5790</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col5" class="data row0 col5" >0.4374</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row0_col6" class="data row0 col6" >0.4634</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col0" class="data row1 col0" >0.8029</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col1" class="data row1 col1" >0.8293</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col2" class="data row1 col2" >0.5185</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col3" class="data row1 col3" >0.8273</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col4" class="data row1 col4" >0.6375</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col5" class="data row1 col5" >0.5117</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row1_col6" class="data row1 col6" >0.5380</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col0" class="data row2 col0" >0.8019</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col1" class="data row2 col1" >0.8229</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col2" class="data row2 col2" >0.5214</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col3" class="data row2 col3" >0.8206</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col4" class="data row2 col4" >0.6376</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col5" class="data row2 col5" >0.5105</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row2_col6" class="data row2 col6" >0.5354</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col0" class="data row3 col0" >0.7943</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col1" class="data row3 col1" >0.8220</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col2" class="data row3 col2" >0.4986</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col3" class="data row3 col3" >0.8140</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col4" class="data row3 col4" >0.6184</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col5" class="data row3 col5" >0.4885</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row3_col6" class="data row3 col6" >0.5160</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col0" class="data row4 col0" >0.7933</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col1" class="data row4 col1" >0.8271</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col2" class="data row4 col2" >0.5043</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col3" class="data row4 col3" >0.8045</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col4" class="data row4 col4" >0.6200</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col5" class="data row4 col5" >0.4881</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row4_col6" class="data row4 col6" >0.5132</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col0" class="data row5 col0" >0.8105</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col1" class="data row5 col1" >0.8214</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col2" class="data row5 col2" >0.5100</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col3" class="data row5 col3" >0.8689</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col4" class="data row5 col4" >0.6427</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col5" class="data row5 col5" >0.5254</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row5_col6" class="data row5 col6" >0.5599</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col0" class="data row6 col0" >0.7876</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col1" class="data row6 col1" >0.8152</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col2" class="data row6 col2" >0.5085</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col3" class="data row6 col3" >0.7817</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col4" class="data row6 col4" >0.6162</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col5" class="data row6 col5" >0.4783</td>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row6_col6" class="data row6 col6" >0.4994</td>
#             </tr>
#             <tr>
#                         <th id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dac0a009_5ff3_11eb_9393_30c9ab536b38row7_co

# %%
pred_holdout = predict_model(blended_2)
# Out:
# <style  type="text/css" >
# </style><table id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col1" class="data row0 col1" >0.7896</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col2" class="data row0 col2" >0.8116</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col3" class="data row0 col3" >0.4862</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col4" class="data row0 col4" >0.7980</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col5" class="data row0 col5" >0.6043</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col6" class="data row0 col6" >0.4722</td>
#                         <td id="T_daf8ca52_5ff3_11eb_8614_30c9ab536b38row0_col7" class="data row0 col7" >0.4991</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(blended_2)

# %%
X_test = pd.DataFrame(x3_test)

# %%
predictions = predict_model(final_model, data = X_test)

#pycaret에서는 score이 label을 맞출 확률이기때문에 output을 제출 양식에 맞게 바꿔줍니다
x = []
for i in range(len(predictions['Score'])):
  if predictions['Label'][i] =='1.0':
    x.append(predictions['Score'][i])
  else:
    x.append(1-predictions['Score'][i])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')
sample_submssion['problem'] = x
sample_submssion.to_csv("best_5.csv", index = False)
